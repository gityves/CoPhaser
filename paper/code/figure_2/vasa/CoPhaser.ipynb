# %% [markdown]
# Data from [High-throughput total RNA sequencing in single cells using VASA-seq.](https://doi.org/10.1038/s41587-022-01361-8)

# %%
import numpy as np
from cophaser import utils
from cophaser.trainer import Trainer
from cophaser.loss import Loss
from cophaser import plotting
from cophaser.model import CoPhaser
from cophaser import gene_sets

import matplotlib.pyplot as plt
import seaborn as sns

import anndata
import scanpy as sc

import pandas as pd

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Data Loading

# %%
# adata = anndata.read_h5ad("../data/cellcycle_maxine/RPE_37C_Rep1_full.h5ad")
DATA_FOLDER = "../../../../data/"
adata = anndata.read_h5ad(
    f"{DATA_FOLDER}cellcycle_maxine/different_cell_types/phase_VASA.h5ad"
)
adata
# Out:
# /home/maxine/miniconda3/envs/CoPhaser_Env/lib/python3.13/site-packages/anndata/_core/anndata.py:1808: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# AnnData object with n_obs × n_vars = 42063 × 16494
#     obs: 'Cell_ID', 'obs_names', 'Stage', 'Dataset', 'G0?', 'UMAP_phase', 'UMI_SUM'
#     var: 'var_names', 'Type'
#     layers: 'matrix', 'spliced', 'unspliced'

# %%
annotation = pd.read_csv(
    f"{DATA_FOLDER}cellcycle_maxine/different_cell_types/umap_LeidenSphaseCelltype_vasa.tsv",
    sep="\t",
    index_col=0,
)
annotation = annotation.reset_index()
annotation["index"].str.split("-").str[0]
annotation["index"] = (
    annotation["index"].str.split("-").str[-1]
    + "_"
    + annotation["index"].str.split("-").str[0]
    + "-"
    + annotation["index"].str.split("-").str[1]
)
annotation = annotation.set_index("index")
annotation
# Out:
#                                  umap1      umap2 batch  leiden  S-phase  \
# index
# AAACGATCCTTACGGG_E6.5-3_i29  12.206623   0.891223  E6.5      29     True
# AAACTGTGCTCTTGAC_E6.5-3_i29  11.330956   0.654213  E6.5      29     True
# AAACTGTGTAAGACGG_E6.5-3_i29   3.544345  -2.354121  E6.5      19    False
# AAATAGCACTTACTCC_E6.5-3_i29  12.215343   0.703546  E6.5      29     True
# AACAGAACTCTGTGGT_E6.5-3_i29  11.676294   0.633441  E6.5      29     True
# ...                                ...        ...   ...     ...      ...
# TGTTATCACGGGTAGT_E9.5-4_i27  -0.351355  17.922290  E9.5      40     True
# TGTTATCAGAATACGC_E9.5-4_i27  16.066618   6.589938  E9.5       4    False
# TGTTATCAGCACCTCT_E9.5-4_i27  16.551199   0.646162  E9.5      20    False
# TGTTATCAGGGAACCT_E9.5-4_i27   8.503787  14.024274  E9.5       5     True
# TGTTATCATGCCTCAC_E9.5-4_i27  13.096477  20.212719  E9.5       1    False
#
#                                                                       Celltype
# index
# AAACGATCCTTACGGG_E6.5-3_i29                                    Epiblast (E6.5)
# AAACTGTGCTCTTGAC_E6.5-3_i29                                    Epiblast (E6.5)
# AAACTGTGTAAGACGG_E6.5-3_i29                                      Trophectoderm
# AAATAGCACTTACTCC_E6.5-3_i29                                    Epiblast (E6.5)
# AACAGAACTCTGTGGT_E6.5-3_i29                                    Epiblast (E6.5)
# ...                                                                        ...
# TGTTATCACGGGTAGT_E9.5-4_i27                                 Mesodermal Unknown
# TGTTATCAGAATACGC_E9.5-4_i27                                    Caudal Epiblast
# TGTTATCAGCACCTCT_E9.5-4_i27                            Dorsal Surface Ectoderm
# TGTTATCAGGGAACCT_E9.5-4_i27  Lateral Plate Mesoderm/Intermediate Mesoderm P...
# TGTTATCATGCCTCAC_E9.5-4_i27                                            Somites
#
# [33662 rows x 6 columns]

# %%
adata.obs = adata.obs.merge(
    annotation[["S-phase", "Celltype"]], how="left", left_on="Cell_ID", right_index=True
)

# %%
adata.layers["spliced"] = adata.layers["spliced"].astype("uint16")
adata.layers["unspliced"] = adata.layers["unspliced"].astype("uint16")

# %%
adata = adata[:, ~adata.var_names.duplicated()].copy()

# %% [markdown]
# # Data Filtering

# %%
sc.pp.filter_genes(adata, min_cells=10)

# %%
# create a new layer copy of the spliced layer
adata.layers["s_norm"] = adata.layers["spliced"].copy()
adata.layers["u_norm"] = adata.layers["unspliced"].copy()

# normalize the spliced layer, adding layer option, indicates which layer we want to normalize
sc.pp.normalize_total(adata, target_sum=1e4, layer="s_norm")
sc.pp.normalize_total(adata, target_sum=1e4, layer="u_norm")

# copy the normalized layer to a new layer, s_log
adata.layers["s_log"] = adata.layers["s_norm"].copy()
adata.layers["u_log"] = adata.layers["u_norm"].copy()

# log transform the normalized layer
sc.pp.log1p(adata, layer="s_log")
sc.pp.log1p(adata, layer="u_log")
# add % unspliced to adata.obs
adata.obs["s_counts"] = adata.layers["spliced"].sum(axis=1)
adata.obs["u_counts"] = adata.layers["unspliced"].sum(axis=1)

adata.obs["percent_unspliced"] = adata.obs["u_counts"] / (
    adata.obs["u_counts"] + adata.obs["s_counts"]
)
# Out:
# WARNING: adata.X seems to be already log-transformed.

# %%
# plot distribution of % unspliced
sns.histplot(adata.obs["percent_unspliced"], bins=100)
# lower threshold for % unspliced
low_percent_unspliced = 0.3
# upper threshold for % unspliced
high_percent_unspliced = 0.7
plt.axvline(low_percent_unspliced, color="red", linestyle="--")
plt.axvline(high_percent_unspliced, color="red", linestyle="--")

# %%
# add total counts to adata.obs
adata.obs["total_counts"] = adata.layers["spliced"].sum(
    axis=1
)  # + adata.layers["unspliced"].sum(axis=1)
# plot distribution of total counts
sns.histplot(adata.obs["total_counts"], bins=100, log_scale=True)
# lower threshold for total counts
low_total_counts = 1500
# upper threshold for total counts
high_total_counts = 50000
plt.axvline(low_total_counts, color="red", linestyle="--")
plt.axvline(high_total_counts, color="red", linestyle="--")

# %%
# filter cells based on thresholds
adata = adata[
    (adata.obs["percent_unspliced"] > low_percent_unspliced)
    & (adata.obs["percent_unspliced"] < high_percent_unspliced)
    & (adata.obs["total_counts"] > low_total_counts)
    & (adata.obs["total_counts"] < high_total_counts)
].copy()

# %%
adata.obs
# Out:
#                             Cell_ID  obs_names Stage      Dataset  G0?  \
# 0      AAACAAACAAAGCCTA_E8.5-19_i36          0  E8.5  E8.5-19_i36  0.0
# 1       AAACAAACAAAGCCTA_E8.5-7_i20          1  E8.5   E8.5-7_i20  0.0
# 2       AAACAAACAACAATCC_E9.5-6_i42          2  E9.5   E9.5-6_i42  0.0
# 3       AAACAAACAACCCTTG_E8.5-2_i16          3  E8.5   E8.5-2_i16  0.0
# 4       AAACAAACAACCCTTG_E9.5-4_i27          4  E9.5   E9.5-4_i27  0.0
# ...                             ...        ...   ...          ...  ...
# 46117   TGTTATCATTAGGACC_E9.5-5_i28      46117  E9.5   E9.5-5_i28  0.0
# 46118   TGTTATCATTCCAGAC_E9.5-5_i28      46118  E9.5   E9.5-5_i28  0.0
# 46120   TGTTATCATTGATCTA_E8.5-2_i16      46120  E8.5   E8.5-2_i16  0.0
# 46121   TGTTATCATTGCATAT_E9.5-8_i44      46121  E9.5   E9.5-8_i44  0.0
# 46123  TGTTATCATTGTCGCC_E8.5-16_i25      46123  E8.5  E8.5-16_i25  0.0
#
#        UMAP_phase  UMI_SUM S-phase                              Celltype  \
# 0        2.234725   3716.0     NaN                                   NaN
# 1        4.659329   6066.0     NaN                                   NaN
# 2        1.721789   6203.0    True               Intermediate Mesoderm I
# 3        5.050425  26326.0     NaN                                   NaN
# 4        2.447364   7234.0    True                     Paraxial Mesoderm
# ...           ...      ...     ...                                   ...
# 46117    6.099113  12009.0   False               Intermediate Mesoderm I
# 46118    1.952546   8341.0    True                     Paraxial Mesoderm
# 46120    6.067719   3548.0   False                               Somites
# 46121    1.767173   4804.0     NaN                                   NaN
# 46123    5.586664  22976.0    True  Spinal cord (differentiated neurons)
#
#        s_counts  u_counts  percent_unspliced  total_counts
# 0          3714      4097           0.524517          3714
# 1          6066      5598           0.479938          6066
# 2          6203      5817           0.483943          6203
# 3         26326     22491           0.460721         26326
# 4          7233     10065           0.581859          7233
# ...         ...       ...                ...           ...
# 46117     12008     12064           0.501163         12008
# 46118      8341      8797           0.513304          8341
# 46120      3548      5096           0.589542          3548
# 46121      4804      5316           0.525296          4804
# 46123     22974     23334           0.503887         22974
#
# [38913 rows x 13 columns]

# %% [markdown]
# # PCA Derived Cell Cycle Phase Inference

# %%
adata.X = adata.layers["spliced"].copy()  # + adata.layers["unspliced"]

# %%
adata_all_genes = adata.copy()
layer_to_use = "spliced"
library_size = adata_all_genes.layers[layer_to_use].sum(axis=1).A1

# %%
# Preprocess data
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
# Out:
# WARNING: adata.X seems to be already log-transformed.

# %%
SMALL_CYCLING_GENE_SET = gene_sets.SMALL_CELL_CYCLE_GENE_SET
adata = adata[:, adata.var_names.isin(SMALL_CYCLING_GENE_SET)]

# %%
len(SMALL_CYCLING_GENE_SET)
# Out:
# 98

# %%
# mean center the adata
adata.X = adata.X - adata.X.mean(axis=1)
# Out:
# /tmp/ipykernel_366708/1782500935.py:2: ImplicitModificationWarning: X should not be a np.matrix, use np.ndarray instead.
#   adata.X = adata.X - adata.X.mean(axis=1)
# /home/maxine/miniconda3/envs/CoPhaser_Env/lib/python3.13/site-packages/anndata/_core/anndata.py:636: FutureWarning: You are attempting to set `X` to a matrix on a view which has non-unique indices. The resulting `adata.X` will likely not equal the value to which you set it. To avoid this potential issue, please make a copy of the data first. In the future, this operation will throw an error.
#   warnings.warn(msg, FutureWarning, stacklevel=1)
# /tmp/ipykernel_366708/1782500935.py:2: ImplicitModificationWarning: Modifying `X` on a view results in data being overridden
#   adata.X = adata.X - adata.X.mean(axis=1)
# /home/maxine/miniconda3/envs/CoPhaser_Env/lib/python3.13/site-packages/scipy/sparse/_index.py:201: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_arrayXarray_sparse(i, j, x)

# %%
# pca on the data
sc.pp.pca(adata)
# plot the pca
sc.pl.pca(adata)
# Out:
# /home/maxine/miniconda3/envs/CoPhaser_Env/lib/python3.13/site-packages/scanpy/preprocessing/_pca/__init__.py:384: ImplicitModificationWarning: Setting element `.obsm['X_pca']` of view, initializing view as actual.
#   adata.obsm[key_obsm] = x_pca

# %%
# add PCA theta to adata.obs
adata.obs["pca_theta"] = np.arctan2(
    adata.obsm["X_pca"][:, 1], adata.obsm["X_pca"][:, 0]
)
adata_all_genes.obs["pca_theta"] = adata.obs["pca_theta"].copy()
adata = adata_all_genes.copy()

# %%
adata.obs["pca_theta"].plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Model Set-Up and Training

# %%
# context genes
g = utils.get_variable_genes(adata)
len(g)
# Out:
# WARNING: adata.X seems to be already log-transformed.
# 2000

# %%
model = CoPhaser(
    SMALL_CYCLING_GENE_SET,
    g,
)
model.load_anndata(adata, layer_to_use="spliced")
trainer = Trainer(
    model,
    Loss.compute_loss,
    entropy_weight_factor=50,
    MI_weight=50,
    closed_circle_weight=10,
)
trainer.train_model(batch_size=2048, subsample=None)
# Out:
# Epoch 1/200, elbo_loss: 1823.8159, kl_div_f: 4.6812, kl_div_z: 38.9147, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -1.8920, entropy_loss: -94.6022, radial_variance: 2.0347, radius: 23.5222, L1_mu_z: 0.0000, MI_loss: 0.0000, total_loss: 1754.7705
# Epoch 2/200, elbo_loss: 1491.3571, kl_div_f: 4.6289, kl_div_z: 41.7612, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -2.6116, entropy_loss: -130.5804, radial_variance: 3.0199, radius: 3.6636, L1_mu_z: 0.0000, MI_loss: 0.0002, total_loss: 1367.4713
# Epoch 3/200, elbo_loss: 1412.2205, kl_div_f: 4.5669, kl_div_z: 41.8788, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -2.9819, entropy_loss: -149.0929, radial_variance: 2.4697, radius: 2.8114, L1_mu_z: 0.0000, MI_loss: 0.0020, total_loss: 1268.5084
# Epoch 4/200, elbo_loss: 1373.8561, kl_div_f: 4.5019, kl_div_z: 42.0407, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3506, entropy_loss: -167.5324, radial_variance: 1.4055, radius: 1.9913, L1_mu_z: 0.0000, MI_loss: 0.0048, total_loss: 1209.9629
# Epoch 5/200, elbo_loss: 1359.5838, kl_div_f: 4.4448, kl_div_z: 42.0585, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3903, entropy_loss: -169.5151, radial_variance: 1.2274, radius: 2.1314, L1_mu_z: 0.0000, MI_loss: 0.0112, total_loss: 1193.9889
# Epoch 6/200, elbo_loss: 1325.1304, kl_div_f: 4.3867, kl_div_z: 42.7219, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3934, entropy_loss: -169.6709, radial_variance: 1.1366, radius: 2.1281, L1_mu_z: 0.0000, MI_loss: 0.0201, total_loss: 1159.7308
# Epoch 7/200, elbo_loss: 1305.0333, kl_div_f: 4.3291, kl_div_z: 42.7977, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3946, entropy_loss: -169.7302, radial_variance: 1.1171, radius: 2.1264, L1_mu_z: 0.0000, MI_loss: 0.0285, total_loss: 1139.9721
# Epoch 8/200, elbo_loss: 1290.6377, kl_div_f: 4.2800, kl_div_z: 42.8142, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3951, entropy_loss: -169.7540, radial_variance: 1.1110, radius: 2.0991, L1_mu_z: 0.0000, MI_loss: 0.0365, total_loss: 1125.9208
# Epoch 9/200, elbo_loss: 1278.8436, kl_div_f: 4.2175, kl_div_z: 42.8215, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3951, entropy_loss: -169.7564, radial_variance: 1.1031, radius: 2.0682, L1_mu_z: 0.0000, MI_loss: 0.0407, total_loss: 1114.2945
# Epoch 10/200, elbo_loss: 1268.6993, kl_div_f: 4.1626, kl_div_z: 42.8232, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3950, entropy_loss: -169.7503, radial_variance: 1.0945, radius: 2.0134, L1_mu_z: 0.0000, MI_loss: 0.0453, total_loss: 1104.3200
# Epoch 11/200, elbo_loss: 1260.0500, kl_div_f: 4.1006, kl_div_z: 42.8249, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3942, entropy_loss: -169.7108, radial_variance: 1.0788, radius: 1.9820, L1_mu_z: 0.0000, MI_loss: 0.0516, total_loss: 1095.9791
# Epoch 12/200, elbo_loss: 1252.7663, kl_div_f: 4.0443, kl_div_z: 42.8060, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3938, entropy_loss: -169.6894, radial_variance: 1.0789, radius: 1.9294, L1_mu_z: 0.0000, MI_loss: 0.0535, total_loss: 1088.7582
# Epoch 13/200, elbo_loss: 1247.4454, kl_div_f: 3.9851, kl_div_z: 42.7922, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3966, entropy_loss: -169.8278, radial_variance: 1.0438, radius: 1.9034, L1_mu_z: 0.0000, MI_loss: 0.0575, total_loss: 1083.4415
# Epoch 14/200, elbo_loss: 1242.1767, kl_div_f: 3.9285, kl_div_z: 42.7855, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3951, entropy_loss: -169.7543, radial_variance: 1.0353, radius: 1.8659, L1_mu_z: 0.0000, MI_loss: 0.0590, total_loss: 1078.2746
# Epoch 15/200, elbo_loss: 1241.6563, kl_div_f: 3.8722, kl_div_z: 42.7649, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3929, entropy_loss: -169.6460, radial_variance: 1.0431, radius: 1.8196, L1_mu_z: 0.0000, MI_loss: 0.0575, total_loss: 1077.7485
# Epoch 16/200, elbo_loss: 1288.4872, kl_div_f: 3.8141, kl_div_z: 43.5095, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3955, entropy_loss: -169.7742, radial_variance: 1.0335, radius: 1.7972, L1_mu_z: 0.0000, MI_loss: 0.0649, total_loss: 1124.7896
# Epoch 17/200, elbo_loss: 1438.1608, kl_div_f: 3.7572, kl_div_z: 42.6592, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.2861, entropy_loss: -164.3034, radial_variance: 1.5617, radius: 1.7542, L1_mu_z: 0.0000, MI_loss: -0.0079, total_loss: 1276.7808
# Epoch 18/200, elbo_loss: 1300.9236, kl_div_f: 3.6991, kl_div_z: 41.9099, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3866, entropy_loss: -169.3287, radial_variance: 1.0522, radius: 1.8326, L1_mu_z: 0.0000, MI_loss: 0.0285, total_loss: 1135.9032
# Epoch 19/200, elbo_loss: 1273.0501, kl_div_f: 3.6404, kl_div_z: 42.0681, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3932, entropy_loss: -169.6598, radial_variance: 0.9756, radius: 1.7639, L1_mu_z: 0.0000, MI_loss: 0.0487, total_loss: 1108.5661
# Epoch 20/200, elbo_loss: 1261.5242, kl_div_f: 3.5834, kl_div_z: 42.1677, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3939, entropy_loss: -169.6926, radial_variance: 1.0072, radius: 1.6911, L1_mu_z: 0.0000, MI_loss: 0.0573, total_loss: 1097.3939
# Epoch 21/200, elbo_loss: 1254.6091, kl_div_f: 3.5267, kl_div_z: 42.2299, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3952, entropy_loss: -169.7600, radial_variance: 0.9666, radius: 1.7077, L1_mu_z: 0.0000, MI_loss: 0.0613, total_loss: 1090.5870
# Epoch 22/200, elbo_loss: 1299.6696, kl_div_f: 3.4694, kl_div_z: 42.3889, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3929, entropy_loss: -169.6472, radial_variance: 0.9681, radius: 1.6779, L1_mu_z: 0.0000, MI_loss: 0.0642, total_loss: 1135.8769
# Epoch 23/200, elbo_loss: 1278.4992, kl_div_f: 3.4115, kl_div_z: 42.3233, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3918, entropy_loss: -169.5922, radial_variance: 0.9597, radius: 1.6739, L1_mu_z: 0.0000, MI_loss: 0.0648, total_loss: 1114.7786
# Epoch 24/200, elbo_loss: 1254.1001, kl_div_f: 3.3540, kl_div_z: 42.2170, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3932, entropy_loss: -169.6620, radial_variance: 0.9533, radius: 1.6702, L1_mu_z: 0.0000, MI_loss: 0.0687, total_loss: 1090.4985
# Epoch 25/200, elbo_loss: 1249.6826, kl_div_f: 3.2959, kl_div_z: 42.2533, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3954, entropy_loss: -169.7676, radial_variance: 0.9610, radius: 1.6710, L1_mu_z: 0.0000, MI_loss: 0.0788, total_loss: 1086.4864
# Epoch 26/200, elbo_loss: 1248.1332, kl_div_f: 3.2390, kl_div_z: 42.2552, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3961, entropy_loss: -169.8044, radial_variance: 0.9771, radius: 1.6791, L1_mu_z: 0.0000, MI_loss: 0.0789, total_loss: 1084.9326
# Epoch 27/200, elbo_loss: 1247.5778, kl_div_f: 3.1816, kl_div_z: 42.2573, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3961, entropy_loss: -169.8073, radial_variance: 0.9715, radius: 1.6793, L1_mu_z: 0.0000, MI_loss: 0.0775, total_loss: 1084.2972
# Epoch 28/200, elbo_loss: 1247.2563, kl_div_f: 3.1238, kl_div_z: 42.2572, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3961, entropy_loss: -169.8075, radial_variance: 0.9671, radius: 1.6833, L1_mu_z: 0.0000, MI_loss: 0.0777, total_loss: 1083.9834
# Epoch 29/200, elbo_loss: 1246.9105, kl_div_f: 3.0661, kl_div_z: 42.2555, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3962, entropy_loss: -169.8105, radial_variance: 0.9690, radius: 1.6839, L1_mu_z: 0.0000, MI_loss: 0.0780, total_loss: 1083.6548
# Epoch 30/200, elbo_loss: 1246.5969, kl_div_f: 3.0088, kl_div_z: 42.2556, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3960, entropy_loss: -169.8006, radial_variance: 0.9638, radius: 1.6839, L1_mu_z: 0.0000, MI_loss: 0.0755, total_loss: 1083.2202
# Epoch 31/200, elbo_loss: 1246.2059, kl_div_f: 2.9513, kl_div_z: 42.2534, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3962, entropy_loss: -169.8117, radial_variance: 0.9625, radius: 1.6830, L1_mu_z: 0.0000, MI_loss: 0.0775, total_loss: 1082.9143
# Epoch 32/200, elbo_loss: 1245.8368, kl_div_f: 2.8937, kl_div_z: 42.2576, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3962, entropy_loss: -168.1216, radial_variance: 0.9591, radius: 1.6806, L1_mu_z: 0.0000, MI_loss: 0.0777, total_loss: 1084.2381
# Epoch 33/200, elbo_loss: 1245.4935, kl_div_f: 2.8366, kl_div_z: 42.2569, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3961, entropy_loss: -166.4445, radial_variance: 0.9613, radius: 1.6816, L1_mu_z: 0.0000, MI_loss: 0.0781, total_loss: 1085.5949
# Epoch 34/200, elbo_loss: 1245.1309, kl_div_f: 2.7791, kl_div_z: 42.2584, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3966, entropy_loss: -164.8114, radial_variance: 0.9608, radius: 1.6810, L1_mu_z: 0.0000, MI_loss: 0.0789, total_loss: 1086.9084
# Epoch 35/200, elbo_loss: 1244.7753, kl_div_f: 2.7216, kl_div_z: 42.2606, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3960, entropy_loss: -163.1413, radial_variance: 0.9589, radius: 1.6790, L1_mu_z: 0.0000, MI_loss: 0.0768, total_loss: 1088.1123
# Epoch 36/200, elbo_loss: 1244.4617, kl_div_f: 2.6643, kl_div_z: 42.2620, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3962, entropy_loss: -161.5271, radial_variance: 0.9531, radius: 1.6792, L1_mu_z: 0.0000, MI_loss: 0.0792, total_loss: 1089.5253
# Epoch 37/200, elbo_loss: 1244.0777, kl_div_f: 2.6068, kl_div_z: 42.2640, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3964, entropy_loss: -159.9300, radial_variance: 0.9555, radius: 1.6784, L1_mu_z: 0.0000, MI_loss: 0.0775, total_loss: 1090.6563
# Epoch 38/200, elbo_loss: 1243.7116, kl_div_f: 2.5494, kl_div_z: 42.2660, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3960, entropy_loss: -158.3213, radial_variance: 0.9558, radius: 1.6754, L1_mu_z: 0.0000, MI_loss: 0.0772, total_loss: 1091.8814
# Epoch 39/200, elbo_loss: 1243.3579, kl_div_f: 2.4921, kl_div_z: 42.2658, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3961, entropy_loss: -156.7485, radial_variance: 0.9534, radius: 1.6735, L1_mu_z: 0.0000, MI_loss: 0.0787, total_loss: 1093.1704
# Epoch 40/200, elbo_loss: 1243.0114, kl_div_f: 2.4348, kl_div_z: 42.2648, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3959, entropy_loss: -155.1816, radial_variance: 0.9557, radius: 1.6711, L1_mu_z: 0.0000, MI_loss: 0.0759, total_loss: 1094.2517
# Epoch 41/200, elbo_loss: 1242.7074, kl_div_f: 2.3774, kl_div_z: 42.2675, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3963, entropy_loss: -153.6551, radial_variance: 0.9554, radius: 1.6703, L1_mu_z: 0.0000, MI_loss: 0.0763, total_loss: 1095.4937
# Epoch 42/200, elbo_loss: 1242.3306, kl_div_f: 2.3202, kl_div_z: 42.2706, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3957, entropy_loss: -152.0979, radial_variance: 0.9498, radius: 1.6650, L1_mu_z: 0.0000, MI_loss: 0.0773, total_loss: 1096.7144
# Epoch 43/200, elbo_loss: 1242.0449, kl_div_f: 2.2630, kl_div_z: 42.2729, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3963, entropy_loss: -150.6109, radial_variance: 0.9550, radius: 1.6659, L1_mu_z: 0.0000, MI_loss: 0.0752, total_loss: 1097.8166
# Epoch 44/200, elbo_loss: 1241.7574, kl_div_f: 2.2058, kl_div_z: 42.2755, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3959, entropy_loss: -149.0944, radial_variance: 0.9513, radius: 1.6647, L1_mu_z: 0.0000, MI_loss: 0.0765, total_loss: 1099.1044
# Epoch 45/200, elbo_loss: 1241.4103, kl_div_f: 2.1487, kl_div_z: 42.2799, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3961, entropy_loss: -147.6221, radial_variance: 0.9514, radius: 1.6602, L1_mu_z: 0.0000, MI_loss: 0.0771, total_loss: 1100.2572
# Epoch 46/200, elbo_loss: 1241.0431, kl_div_f: 2.0916, kl_div_z: 42.2829, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3962, entropy_loss: -146.1571, radial_variance: 0.9538, radius: 1.6602, L1_mu_z: 0.0000, MI_loss: 0.0732, total_loss: 1101.1590
# Epoch 47/200, elbo_loss: 1240.6677, kl_div_f: 2.1593, kl_div_z: 42.2804, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3961, entropy_loss: -144.6982, radial_variance: 0.9500, radius: 1.6605, L1_mu_z: 0.0000, MI_loss: 0.0767, total_loss: 1102.4132
# Epoch 48/200, elbo_loss: 1239.9677, kl_div_f: 3.3170, kl_div_z: 42.2799, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3961, entropy_loss: -143.2570, radial_variance: 0.9479, radius: 1.6570, L1_mu_z: 0.0000, MI_loss: 0.0819, total_loss: 1103.4107
# Epoch 49/200, elbo_loss: 1239.6221, kl_div_f: 3.3914, kl_div_z: 42.2802, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3962, entropy_loss: -141.8370, radial_variance: 0.9508, radius: 1.6560, L1_mu_z: 0.0000, MI_loss: 0.0833, total_loss: 1104.5564
# Epoch 50/200, elbo_loss: 1239.3021, kl_div_f: 3.2120, kl_div_z: 42.2821, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3961, entropy_loss: -140.4223, radial_variance: 0.9467, radius: 1.6526, L1_mu_z: 0.0000, MI_loss: 0.0811, total_loss: 1105.5325
# Epoch 51/200, elbo_loss: 1238.9678, kl_div_f: 3.2357, kl_div_z: 42.2840, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3965, entropy_loss: -139.0419, radial_variance: 0.9541, radius: 1.6514, L1_mu_z: 0.0000, MI_loss: 0.0787, total_loss: 1106.4670
# Epoch 52/200, elbo_loss: 1257.3549, kl_div_f: 3.0128, kl_div_z: 42.2615, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -2.9628, entropy_loss: -120.0803, radial_variance: 9.6747, radius: 24.2091, L1_mu_z: 0.0000, MI_loss: -0.0297, total_loss: 1169.6743
# Epoch 53/200, elbo_loss: 1246.0180, kl_div_f: 3.1639, kl_div_z: 42.2782, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3830, entropy_loss: -135.7447, radial_variance: 1.5732, radius: 1.7354, L1_mu_z: 0.0000, MI_loss: 0.1017, total_loss: 1118.6690
# Epoch 54/200, elbo_loss: 1242.5680, kl_div_f: 3.1599, kl_div_z: 42.2786, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3413, entropy_loss: -132.7371, radial_variance: 1.2795, radius: 1.6338, L1_mu_z: 0.0000, MI_loss: 0.0946, total_loss: 1117.4759
# Epoch 55/200, elbo_loss: 1240.4897, kl_div_f: 3.1426, kl_div_z: 42.2840, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3837, entropy_loss: -133.0857, radial_variance: 1.0811, radius: 1.4713, L1_mu_z: 0.0000, MI_loss: 0.1021, total_loss: 1115.0594
# Epoch 56/200, elbo_loss: 1238.7489, kl_div_f: 3.2048, kl_div_z: 42.2753, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3911, entropy_loss: -132.0484, radial_variance: 0.9499, radius: 1.4172, L1_mu_z: 0.0000, MI_loss: 0.1054, total_loss: 1114.3372
# Epoch 57/200, elbo_loss: 1238.2450, kl_div_f: 3.2081, kl_div_z: 42.2790, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3907, entropy_loss: -130.7187, radial_variance: 0.9302, radius: 1.4042, L1_mu_z: 0.0000, MI_loss: 0.1051, total_loss: 1115.1169
# Epoch 58/200, elbo_loss: 1238.1112, kl_div_f: 3.1855, kl_div_z: 42.2759, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3861, entropy_loss: -129.2429, radial_variance: 0.8518, radius: 1.4102, L1_mu_z: 0.0000, MI_loss: 0.1057, total_loss: 1116.4161
# Epoch 59/200, elbo_loss: 1237.8897, kl_div_f: 3.2227, kl_div_z: 42.2752, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3956, entropy_loss: -128.3173, radial_variance: 0.8566, radius: 1.3484, L1_mu_z: 0.0000, MI_loss: 0.1085, total_loss: 1117.2017
# Epoch 60/200, elbo_loss: 1237.9571, kl_div_f: 3.2164, kl_div_z: 42.2761, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3956, entropy_loss: -127.0391, radial_variance: 0.8254, radius: 1.3822, L1_mu_z: 0.0000, MI_loss: 0.0871, total_loss: 1117.4790
# Epoch 61/200, elbo_loss: 1237.9446, kl_div_f: 3.2243, kl_div_z: 42.2745, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3931, entropy_loss: -125.6847, radial_variance: 0.8418, radius: 1.3718, L1_mu_z: 0.0000, MI_loss: 0.0776, total_loss: 1118.3559
# Epoch 62/200, elbo_loss: 1237.7893, kl_div_f: 3.2982, kl_div_z: 42.2809, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3939, entropy_loss: -124.4613, radial_variance: 0.8308, radius: 1.4372, L1_mu_z: 0.0000, MI_loss: 0.0784, total_loss: 1119.5176
# Epoch 63/200, elbo_loss: 1237.5696, kl_div_f: 3.2821, kl_div_z: 42.2779, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3959, entropy_loss: -123.2982, radial_variance: 0.8530, radius: 1.3717, L1_mu_z: 0.0000, MI_loss: 0.0772, total_loss: 1120.3576
# Epoch 64/200, elbo_loss: 1237.3694, kl_div_f: 3.2876, kl_div_z: 42.2785, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3962, entropy_loss: -122.0804, radial_variance: 0.8294, radius: 1.3758, L1_mu_z: 0.0000, MI_loss: 0.0755, total_loss: 1121.2708
# Epoch 65/200, elbo_loss: 1236.9186, kl_div_f: 3.2665, kl_div_z: 42.2792, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3974, entropy_loss: -120.9082, radial_variance: 0.8208, radius: 1.3385, L1_mu_z: 0.0000, MI_loss: 0.0701, total_loss: 1121.6757
# Epoch 66/200, elbo_loss: 1236.8140, kl_div_f: 3.2374, kl_div_z: 42.2810, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3954, entropy_loss: -119.6346, radial_variance: 0.8149, radius: 1.3703, L1_mu_z: 0.0000, MI_loss: 0.0743, total_loss: 1123.0816
# Epoch 67/200, elbo_loss: 1237.3519, kl_div_f: 3.2821, kl_div_z: 42.2780, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3934, entropy_loss: -118.3747, radial_variance: 0.8387, radius: 1.3681, L1_mu_z: 0.0000, MI_loss: 0.0633, total_loss: 1124.3504
# Epoch 68/200, elbo_loss: 1236.8365, kl_div_f: 3.3161, kl_div_z: 42.2766, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3966, entropy_loss: -117.3085, radial_variance: 0.8313, radius: 1.3443, L1_mu_z: 0.0000, MI_loss: 0.0582, total_loss: 1124.6114
# Epoch 69/200, elbo_loss: 1236.4467, kl_div_f: 3.3063, kl_div_z: 42.2882, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3956, entropy_loss: -116.1064, radial_variance: 0.8374, radius: 1.3443, L1_mu_z: 0.0000, MI_loss: 0.0683, total_loss: 1125.9387
# Epoch 70/200, elbo_loss: 1236.0984, kl_div_f: 3.2769, kl_div_z: 42.2887, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3957, entropy_loss: -114.9531, radial_variance: 0.8273, radius: 1.3653, L1_mu_z: 0.0000, MI_loss: 0.0646, total_loss: 1126.5705
# Epoch 71/200, elbo_loss: 1236.0724, kl_div_f: 3.3091, kl_div_z: 42.2860, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3923, entropy_loss: -113.6979, radial_variance: 0.8512, radius: 1.3601, L1_mu_z: 0.0000, MI_loss: 0.0615, total_loss: 1127.6596
# Epoch 72/200, elbo_loss: 1235.9547, kl_div_f: 3.3515, kl_div_z: 42.2847, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3939, entropy_loss: -112.6194, radial_variance: 0.8187, radius: 1.3399, L1_mu_z: 0.0000, MI_loss: 0.0607, total_loss: 1128.5282
# Epoch 73/200, elbo_loss: 1237.2062, kl_div_f: 3.3006, kl_div_z: 42.2854, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3837, entropy_loss: -111.1617, radial_variance: 0.9169, radius: 1.4464, L1_mu_z: 0.0000, MI_loss: 0.0527, total_loss: 1131.0402
# Epoch 74/200, elbo_loss: 1237.0052, kl_div_f: 3.2443, kl_div_z: 42.2908, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3872, entropy_loss: -110.1706, radial_variance: 0.9157, radius: 1.4394, L1_mu_z: 0.0000, MI_loss: 0.0485, total_loss: 1131.6134
# Epoch 75/200, elbo_loss: 1236.2475, kl_div_f: 3.2787, kl_div_z: 42.2853, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3932, entropy_loss: -109.2665, radial_variance: 0.8698, radius: 1.3862, L1_mu_z: 0.0000, MI_loss: 0.0498, total_loss: 1131.7279
# Epoch 76/200, elbo_loss: 1235.3140, kl_div_f: 3.3102, kl_div_z: 42.2952, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3969, entropy_loss: -108.2968, radial_variance: 0.8039, radius: 1.3360, L1_mu_z: 0.0000, MI_loss: 0.0572, total_loss: 1132.0173
# Epoch 77/200, elbo_loss: 1235.1162, kl_div_f: 3.3250, kl_div_z: 42.2930, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3973, entropy_loss: -107.2321, radial_variance: 0.8196, radius: 1.3205, L1_mu_z: 0.0000, MI_loss: 0.0629, total_loss: 1133.1683
# Epoch 78/200, elbo_loss: 1235.0378, kl_div_f: 3.3191, kl_div_z: 42.2969, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3965, entropy_loss: -106.1416, radial_variance: 0.8104, radius: 1.3370, L1_mu_z: 0.0000, MI_loss: 0.0516, total_loss: 1133.6234
# Epoch 79/200, elbo_loss: 1234.7834, kl_div_f: 3.3349, kl_div_z: 42.2964, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3959, entropy_loss: -105.0662, radial_variance: 0.8153, radius: 1.3228, L1_mu_z: 0.0000, MI_loss: 0.0527, total_loss: 1134.4927
# Epoch 80/200, elbo_loss: 1234.7349, kl_div_f: 3.3140, kl_div_z: 42.3032, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3941, entropy_loss: -103.9654, radial_variance: 0.8186, radius: 1.3364, L1_mu_z: 0.0000, MI_loss: 0.0522, total_loss: 1135.5346
# Epoch 81/200, elbo_loss: 1234.2650, kl_div_f: 3.3586, kl_div_z: 42.3057, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3965, entropy_loss: -103.0043, radial_variance: 0.8459, radius: 1.3100, L1_mu_z: 0.0000, MI_loss: 0.0544, total_loss: 1136.1355
# Epoch 82/200, elbo_loss: 1234.1576, kl_div_f: 3.3756, kl_div_z: 42.2965, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3957, entropy_loss: -101.9543, radial_variance: 0.8142, radius: 1.3105, L1_mu_z: 0.0000, MI_loss: 0.0521, total_loss: 1136.9333
# Epoch 83/200, elbo_loss: 1234.5346, kl_div_f: 3.3069, kl_div_z: 42.3047, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3919, entropy_loss: -100.8290, radial_variance: 0.8516, radius: 1.3443, L1_mu_z: 0.0000, MI_loss: 0.0474, total_loss: 1138.2717
# Epoch 84/200, elbo_loss: 1234.0769, kl_div_f: 3.3108, kl_div_z: 42.2987, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3912, entropy_loss: -99.8045, radial_variance: 0.8428, radius: 1.3501, L1_mu_z: 0.0000, MI_loss: 0.0513, total_loss: 1139.0307
# Epoch 85/200, elbo_loss: 1233.4615, kl_div_f: 3.3325, kl_div_z: 42.2984, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3940, entropy_loss: -98.8917, radial_variance: 0.8042, radius: 1.3050, L1_mu_z: 0.0000, MI_loss: 0.0554, total_loss: 1139.4503
# Epoch 86/200, elbo_loss: 1233.4126, kl_div_f: 3.3696, kl_div_z: 42.3037, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3966, entropy_loss: -97.9824, radial_variance: 0.8065, radius: 1.2982, L1_mu_z: 0.0000, MI_loss: 0.0478, total_loss: 1139.9273
# Epoch 87/200, elbo_loss: 1233.2889, kl_div_f: 3.3572, kl_div_z: 42.3030, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3958, entropy_loss: -96.9845, radial_variance: 0.8081, radius: 1.3207, L1_mu_z: 0.0000, MI_loss: 0.0502, total_loss: 1140.9428
# Epoch 88/200, elbo_loss: 1232.7913, kl_div_f: 3.3320, kl_div_z: 42.3023, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3965, entropy_loss: -96.0393, radial_variance: 0.8130, radius: 1.2965, L1_mu_z: 0.0000, MI_loss: 0.0531, total_loss: 1141.5177
# Epoch 89/200, elbo_loss: 1232.6068, kl_div_f: 3.3391, kl_div_z: 42.3062, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3937, entropy_loss: -95.0063, radial_variance: 0.7978, radius: 1.2794, L1_mu_z: 0.0000, MI_loss: 0.0506, total_loss: 1142.2055
# Epoch 90/200, elbo_loss: 1232.4583, kl_div_f: 3.3921, kl_div_z: 42.3046, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3953, entropy_loss: -94.1045, radial_variance: 0.8014, radius: 1.2628, L1_mu_z: 0.0000, MI_loss: 0.0567, total_loss: 1143.2511
# Epoch 91/200, elbo_loss: 1232.2630, kl_div_f: 3.3984, kl_div_z: 42.3106, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3960, entropy_loss: -93.1886, radial_variance: 0.7763, radius: 1.2913, L1_mu_z: 0.0000, MI_loss: 0.0527, total_loss: 1143.7770
# Epoch 92/200, elbo_loss: 1232.1851, kl_div_f: 3.4254, kl_div_z: 42.3042, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3952, entropy_loss: -92.2406, radial_variance: 0.8250, radius: 1.2723, L1_mu_z: 0.0000, MI_loss: 0.0556, total_loss: 1144.8236
# Epoch 93/200, elbo_loss: 1231.9572, kl_div_f: 3.3990, kl_div_z: 42.3071, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3951, entropy_loss: -91.3198, radial_variance: 0.8035, radius: 1.2666, L1_mu_z: 0.0000, MI_loss: 0.0521, total_loss: 1145.3116
# Epoch 94/200, elbo_loss: 1231.6015, kl_div_f: 3.3811, kl_div_z: 42.3100, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3957, entropy_loss: -90.4259, radial_variance: 0.7830, radius: 1.2562, L1_mu_z: 0.0000, MI_loss: 0.0564, total_loss: 1146.0371
# Epoch 95/200, elbo_loss: 1231.7306, kl_div_f: 3.3954, kl_div_z: 42.3177, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3960, entropy_loss: -89.5336, radial_variance: 0.8175, radius: 1.2582, L1_mu_z: 0.0000, MI_loss: 0.0508, total_loss: 1146.8115
# Epoch 96/200, elbo_loss: 1231.5805, kl_div_f: 3.3663, kl_div_z: 42.3070, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3944, entropy_loss: -88.6029, radial_variance: 0.7986, radius: 1.2898, L1_mu_z: 0.0000, MI_loss: 0.0534, total_loss: 1147.7347
# Epoch 97/200, elbo_loss: 1231.3778, kl_div_f: 3.4146, kl_div_z: 42.3173, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3946, entropy_loss: -87.7261, radial_variance: 0.8326, radius: 1.2683, L1_mu_z: 0.0000, MI_loss: 0.0536, total_loss: 1148.4319
# Epoch 98/200, elbo_loss: 1231.1790, kl_div_f: 3.4076, kl_div_z: 42.3105, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3958, entropy_loss: -86.8818, radial_variance: 0.7850, radius: 1.2631, L1_mu_z: 0.0000, MI_loss: 0.0554, total_loss: 1149.1140
# Epoch 99/200, elbo_loss: 1231.2839, kl_div_f: 3.3797, kl_div_z: 42.3101, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3939, entropy_loss: -85.9704, radial_variance: 0.8038, radius: 1.2894, L1_mu_z: 0.0000, MI_loss: 0.0471, total_loss: 1149.7637
# Epoch 100/200, elbo_loss: 1230.8144, kl_div_f: 3.3842, kl_div_z: 42.3119, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3941, entropy_loss: -85.1197, radial_variance: 0.8062, radius: 1.2311, L1_mu_z: 0.0000, MI_loss: 0.0529, total_loss: 1150.3763
# Epoch 101/200, elbo_loss: 1230.6670, kl_div_f: 3.3924, kl_div_z: 42.3069, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3945, entropy_loss: -84.2825, radial_variance: 0.8064, radius: 1.2519, L1_mu_z: 0.0000, MI_loss: 0.0548, total_loss: 1151.1842
# Epoch 102/200, elbo_loss: 1230.6032, kl_div_f: 3.4097, kl_div_z: 42.3074, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3925, entropy_loss: -83.3953, radial_variance: 0.7863, radius: 1.2736, L1_mu_z: 0.0000, MI_loss: 0.0577, total_loss: 1152.1505
# Epoch 103/200, elbo_loss: 1230.3318, kl_div_f: 3.3906, kl_div_z: 42.3098, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3942, entropy_loss: -82.6057, radial_variance: 0.7818, radius: 1.2816, L1_mu_z: 0.0000, MI_loss: 0.0525, total_loss: 1152.4157
# Epoch 104/200, elbo_loss: 1230.0448, kl_div_f: 3.4064, kl_div_z: 42.3134, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3942, entropy_loss: -81.7858, radial_variance: 0.7843, radius: 1.2569, L1_mu_z: 0.0000, MI_loss: 0.0526, total_loss: 1152.9306
# Epoch 105/200, elbo_loss: 1229.8053, kl_div_f: 3.4391, kl_div_z: 42.3168, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3946, entropy_loss: -80.9811, radial_variance: 0.7707, radius: 1.2622, L1_mu_z: 0.0000, MI_loss: 0.0557, total_loss: 1153.6446
# Epoch 106/200, elbo_loss: 1229.9099, kl_div_f: 3.4068, kl_div_z: 42.3071, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3936, entropy_loss: -80.1500, radial_variance: 0.8039, radius: 1.2814, L1_mu_z: 0.0000, MI_loss: 0.0518, total_loss: 1154.4377
# Epoch 107/200, elbo_loss: 1229.5762, kl_div_f: 3.4218, kl_div_z: 42.3189, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3938, entropy_loss: -79.3577, radial_variance: 0.7710, radius: 1.2745, L1_mu_z: 0.0000, MI_loss: 0.0559, total_loss: 1155.0603
# Epoch 108/200, elbo_loss: 1229.4147, kl_div_f: 3.4279, kl_div_z: 42.3127, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3948, entropy_loss: -78.5912, radial_variance: 0.7959, radius: 1.2336, L1_mu_z: 0.0000, MI_loss: 0.0547, total_loss: 1155.5872
# Epoch 109/200, elbo_loss: 1229.3106, kl_div_f: 3.5630, kl_div_z: 42.3259, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3945, entropy_loss: -77.8040, radial_variance: 0.7909, radius: 1.2419, L1_mu_z: 0.0000, MI_loss: 0.0499, total_loss: 1156.0340
# Epoch 110/200, elbo_loss: 1229.4853, kl_div_f: 3.7389, kl_div_z: 42.3167, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3898, entropy_loss: -76.9216, radial_variance: 0.7831, radius: 1.2701, L1_mu_z: 0.0000, MI_loss: 0.0484, total_loss: 1157.0386
# Epoch 111/200, elbo_loss: 1228.9246, kl_div_f: 3.7194, kl_div_z: 42.3171, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3936, entropy_loss: -76.2425, radial_variance: 0.7615, radius: 1.2498, L1_mu_z: 0.0000, MI_loss: 0.0574, total_loss: 1157.5649
# Epoch 112/200, elbo_loss: 1228.9208, kl_div_f: 3.6566, kl_div_z: 42.3195, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3937, entropy_loss: -75.4852, radial_variance: 0.7823, radius: 1.2397, L1_mu_z: 0.0000, MI_loss: 0.0586, total_loss: 1158.3882
# Epoch 113/200, elbo_loss: 1228.6293, kl_div_f: 3.5855, kl_div_z: 42.3121, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3919, entropy_loss: -74.6957, radial_variance: 0.7594, radius: 1.2341, L1_mu_z: 0.0000, MI_loss: 0.0561, total_loss: 1158.7307
# Epoch 114/200, elbo_loss: 1228.3788, kl_div_f: 3.5396, kl_div_z: 42.3152, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3944, entropy_loss: -74.0062, radial_variance: 0.7632, radius: 1.2046, L1_mu_z: 0.0000, MI_loss: 0.0548, total_loss: 1159.0812
# Epoch 115/200, elbo_loss: 1228.5321, kl_div_f: 3.5573, kl_div_z: 42.3189, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3923, entropy_loss: -73.2243, radial_variance: 0.7825, radius: 1.2231, L1_mu_z: 0.0000, MI_loss: 0.0502, total_loss: 1159.8228
# Epoch 116/200, elbo_loss: 1228.1608, kl_div_f: 3.5293, kl_div_z: 42.3186, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3942, entropy_loss: -72.5362, radial_variance: 0.7790, radius: 1.2238, L1_mu_z: 0.0000, MI_loss: 0.0551, total_loss: 1160.3831
# Epoch 117/200, elbo_loss: 1228.0898, kl_div_f: 3.4814, kl_div_z: 42.3203, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3914, entropy_loss: -71.7549, radial_variance: 0.7679, radius: 1.2145, L1_mu_z: 0.0000, MI_loss: 0.0490, total_loss: 1160.7649
# Epoch 118/200, elbo_loss: 1229.0851, kl_div_f: 3.4476, kl_div_z: 42.3172, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3768, entropy_loss: -70.7362, radial_variance: 0.9057, radius: 1.2782, L1_mu_z: 0.0000, MI_loss: 0.0502, total_loss: 1163.0429
# Epoch 119/200, elbo_loss: 1227.7364, kl_div_f: 3.4278, kl_div_z: 42.3158, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3908, entropy_loss: -70.3223, radial_variance: 0.7725, radius: 1.2143, L1_mu_z: 0.0000, MI_loss: 0.0554, total_loss: 1162.1718
# Epoch 120/200, elbo_loss: 1227.5917, kl_div_f: 3.4795, kl_div_z: 42.3189, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3941, entropy_loss: -69.6896, radial_variance: 0.7646, radius: 1.2062, L1_mu_z: 0.0000, MI_loss: 0.0527, total_loss: 1162.5102
# Epoch 121/200, elbo_loss: 1227.5536, kl_div_f: 3.4951, kl_div_z: 42.3206, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3931, entropy_loss: -68.9772, radial_variance: 0.7668, radius: 1.2013, L1_mu_z: 0.0000, MI_loss: 0.0530, total_loss: 1163.1940
# Epoch 122/200, elbo_loss: 1227.4758, kl_div_f: 3.4781, kl_div_z: 42.3198, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3913, entropy_loss: -68.2549, radial_variance: 0.7818, radius: 1.2078, L1_mu_z: 0.0000, MI_loss: 0.0501, total_loss: 1163.7162
# Epoch 123/200, elbo_loss: 1227.2947, kl_div_f: 3.4747, kl_div_z: 42.3131, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3888, entropy_loss: -67.5256, radial_variance: 0.7696, radius: 1.1877, L1_mu_z: 0.0000, MI_loss: 0.0546, total_loss: 1164.4553
# Epoch 124/200, elbo_loss: 1227.0706, kl_div_f: 3.4819, kl_div_z: 42.3220, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3933, entropy_loss: -66.9424, radial_variance: 0.7530, radius: 1.2055, L1_mu_z: 0.0000, MI_loss: 0.0565, total_loss: 1164.9130
# Epoch 125/200, elbo_loss: 1227.5012, kl_div_f: 3.4860, kl_div_z: 42.3166, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3900, entropy_loss: -66.2105, radial_variance: 0.8151, radius: 1.2471, L1_mu_z: 0.0000, MI_loss: 0.0482, total_loss: 1165.7606
# Epoch 126/200, elbo_loss: 1226.8202, kl_div_f: 3.4829, kl_div_z: 42.3248, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3917, entropy_loss: -65.5862, radial_variance: 0.7773, radius: 1.1945, L1_mu_z: 0.0000, MI_loss: 0.0559, total_loss: 1166.0011
# Epoch 127/200, elbo_loss: 1226.5587, kl_div_f: 3.4873, kl_div_z: 42.3220, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3902, entropy_loss: -64.9036, radial_variance: 0.7530, radius: 1.1696, L1_mu_z: 0.0000, MI_loss: 0.0590, total_loss: 1166.5255
# Epoch 128/200, elbo_loss: 1226.7637, kl_div_f: 3.4953, kl_div_z: 42.3257, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3913, entropy_loss: -64.2798, radial_variance: 0.7832, radius: 1.2039, L1_mu_z: 0.0000, MI_loss: 0.0535, total_loss: 1167.1464
# Epoch 129/200, elbo_loss: 1226.6036, kl_div_f: 3.4900, kl_div_z: 42.3249, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3896, entropy_loss: -63.6069, radial_variance: 0.7672, radius: 1.2045, L1_mu_z: 0.0000, MI_loss: 0.0544, total_loss: 1167.6906
# Epoch 130/200, elbo_loss: 1226.2290, kl_div_f: 3.4966, kl_div_z: 42.3213, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3913, entropy_loss: -63.0070, radial_variance: 0.7514, radius: 1.1650, L1_mu_z: 0.0000, MI_loss: 0.0589, total_loss: 1168.0828
# Epoch 131/200, elbo_loss: 1226.3938, kl_div_f: 3.4874, kl_div_z: 42.3167, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3887, entropy_loss: -62.3323, radial_variance: 0.7696, radius: 1.1795, L1_mu_z: 0.0000, MI_loss: 0.0564, total_loss: 1168.8320
# Epoch 132/200, elbo_loss: 1226.0895, kl_div_f: 3.5133, kl_div_z: 42.3184, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3917, entropy_loss: -61.7665, radial_variance: 0.7655, radius: 1.1733, L1_mu_z: 0.0000, MI_loss: 0.0594, total_loss: 1169.2342
# Epoch 133/200, elbo_loss: 1226.0349, kl_div_f: 3.5141, kl_div_z: 42.3222, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3930, entropy_loss: -61.1751, radial_variance: 0.7624, radius: 1.1855, L1_mu_z: 0.0000, MI_loss: 0.0578, total_loss: 1169.6997
# Epoch 134/200, elbo_loss: 1226.0413, kl_div_f: 3.4994, kl_div_z: 42.3110, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3923, entropy_loss: -60.5539, radial_variance: 0.7812, radius: 1.1877, L1_mu_z: 0.0000, MI_loss: 0.0580, total_loss: 1170.3582
# Epoch 135/200, elbo_loss: 1225.6594, kl_div_f: 3.4883, kl_div_z: 42.3220, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3929, entropy_loss: -59.9621, radial_variance: 0.7612, radius: 1.1592, L1_mu_z: 0.0000, MI_loss: 0.0577, total_loss: 1170.5031
# Epoch 136/200, elbo_loss: 1225.4794, kl_div_f: 3.4771, kl_div_z: 42.3211, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3937, entropy_loss: -59.3795, radial_variance: 0.7520, radius: 1.1579, L1_mu_z: 0.0000, MI_loss: 0.0563, total_loss: 1170.8243
# Epoch 137/200, elbo_loss: 1226.3604, kl_div_f: 3.4763, kl_div_z: 42.3227, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3856, entropy_loss: -58.6482, radial_variance: 0.8690, radius: 1.2433, L1_mu_z: 0.0000, MI_loss: 0.0448, total_loss: 1172.0644
# Epoch 138/200, elbo_loss: 1225.4133, kl_div_f: 3.5105, kl_div_z: 42.3151, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3914, entropy_loss: -58.1632, radial_variance: 0.7811, radius: 1.1525, L1_mu_z: 0.0000, MI_loss: 0.0572, total_loss: 1172.0419
# Epoch 139/200, elbo_loss: 1225.2173, kl_div_f: 3.5103, kl_div_z: 42.3184, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3902, entropy_loss: -57.5646, radial_variance: 0.7652, radius: 1.1507, L1_mu_z: 0.0000, MI_loss: 0.0568, total_loss: 1172.4079
# Epoch 140/200, elbo_loss: 1225.1683, kl_div_f: 3.4963, kl_div_z: 42.3243, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3908, entropy_loss: -57.0017, radial_variance: 0.7473, radius: 1.1793, L1_mu_z: 0.0000, MI_loss: 0.0539, total_loss: 1172.7904
# Epoch 141/200, elbo_loss: 1224.8036, kl_div_f: 3.4802, kl_div_z: 42.3226, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3917, entropy_loss: -56.4507, radial_variance: 0.7538, radius: 1.1406, L1_mu_z: 0.0000, MI_loss: 0.0575, total_loss: 1173.1229
# Epoch 142/200, elbo_loss: 1225.3501, kl_div_f: 3.4666, kl_div_z: 42.3299, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3901, entropy_loss: -55.8616, radial_variance: 0.8048, radius: 1.2035, L1_mu_z: 0.0000, MI_loss: 0.0497, total_loss: 1173.9804
# Epoch 143/200, elbo_loss: 1224.7631, kl_div_f: 3.4569, kl_div_z: 42.3270, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3885, entropy_loss: -55.2796, radial_variance: 0.7598, radius: 1.1338, L1_mu_z: 0.0000, MI_loss: 0.0567, total_loss: 1174.2140
# Epoch 144/200, elbo_loss: 1224.7438, kl_div_f: 3.4693, kl_div_z: 42.3220, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3882, entropy_loss: -54.7253, radial_variance: 0.7646, radius: 1.1572, L1_mu_z: 0.0000, MI_loss: 0.0526, total_loss: 1174.5692
# Epoch 145/200, elbo_loss: 1224.4193, kl_div_f: 3.4908, kl_div_z: 42.3283, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3921, entropy_loss: -54.2421, radial_variance: 0.7453, radius: 1.1813, L1_mu_z: 0.0000, MI_loss: 0.0572, total_loss: 1174.9614
# Epoch 146/200, elbo_loss: 1224.4799, kl_div_f: 3.5354, kl_div_z: 42.3265, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3855, entropy_loss: -53.5979, radial_variance: 0.7801, radius: 1.1415, L1_mu_z: 0.0000, MI_loss: 0.0598, total_loss: 1175.7944
# Epoch 147/200, elbo_loss: 1224.2981, kl_div_f: 3.5063, kl_div_z: 42.3241, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3893, entropy_loss: -53.1252, radial_variance: 0.7714, radius: 1.1446, L1_mu_z: 0.0000, MI_loss: 0.0651, total_loss: 1176.3446
# Epoch 148/200, elbo_loss: 1224.3282, kl_div_f: 3.4941, kl_div_z: 42.3239, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3878, entropy_loss: -52.5729, radial_variance: 0.7705, radius: 1.1746, L1_mu_z: 0.0000, MI_loss: 0.0593, total_loss: 1176.6668
# Epoch 149/200, elbo_loss: 1224.2312, kl_div_f: 3.4886, kl_div_z: 42.3249, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3890, entropy_loss: -52.0676, radial_variance: 0.7820, radius: 1.1655, L1_mu_z: 0.0000, MI_loss: 0.0579, total_loss: 1177.0050
# Epoch 150/200, elbo_loss: 1223.8110, kl_div_f: 3.4857, kl_div_z: 42.3251, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3893, entropy_loss: -51.5552, radial_variance: 0.7390, radius: 1.1449, L1_mu_z: 0.0000, MI_loss: 0.0602, total_loss: 1177.1517
# Epoch 151/200, elbo_loss: 1223.9313, kl_div_f: 3.4994, kl_div_z: 42.3326, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3867, entropy_loss: -51.0026, radial_variance: 0.7616, radius: 1.1395, L1_mu_z: 0.0000, MI_loss: 0.0578, total_loss: 1177.7177
# Epoch 152/200, elbo_loss: 1224.0583, kl_div_f: 3.4860, kl_div_z: 42.3286, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3888, entropy_loss: -50.5266, radial_variance: 0.7645, radius: 1.1666, L1_mu_z: 0.0000, MI_loss: 0.0564, total_loss: 1178.2844
# Epoch 153/200, elbo_loss: 1224.6110, kl_div_f: 3.4777, kl_div_z: 42.3319, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3832, entropy_loss: -49.9415, radial_variance: 0.8353, radius: 1.2035, L1_mu_z: 0.0000, MI_loss: 0.0519, total_loss: 1179.3016
# Epoch 154/200, elbo_loss: 1223.4530, kl_div_f: 3.4732, kl_div_z: 42.3279, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3883, entropy_loss: -49.5189, radial_variance: 0.7366, radius: 1.1292, L1_mu_z: 0.0000, MI_loss: 0.0643, total_loss: 1179.0146
# Epoch 155/200, elbo_loss: 1223.6544, kl_div_f: 3.5320, kl_div_z: 42.3324, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3912, entropy_loss: -49.0680, radial_variance: 0.7627, radius: 1.1571, L1_mu_z: 0.0000, MI_loss: 0.0532, total_loss: 1179.1666
# Epoch 156/200, elbo_loss: 1223.3663, kl_div_f: 3.5154, kl_div_z: 42.3326, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3907, entropy_loss: -48.5723, radial_variance: 0.7406, radius: 1.1336, L1_mu_z: 0.0000, MI_loss: 0.0547, total_loss: 1179.4028
# Epoch 157/200, elbo_loss: 1223.2997, kl_div_f: 3.4803, kl_div_z: 42.3294, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3878, entropy_loss: -48.0477, radial_variance: 0.7767, radius: 1.1133, L1_mu_z: 0.0000, MI_loss: 0.0650, total_loss: 1180.3901
# Epoch 158/200, elbo_loss: 1223.6981, kl_div_f: 3.4628, kl_div_z: 42.3392, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3867, entropy_loss: -47.5544, radial_variance: 0.8060, radius: 1.1483, L1_mu_z: 0.0000, MI_loss: 0.0522, total_loss: 1180.7061
# Epoch 159/200, elbo_loss: 1223.2330, kl_div_f: 3.4678, kl_div_z: 42.3360, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3850, entropy_loss: -47.0577, radial_variance: 0.7647, radius: 1.1581, L1_mu_z: 0.0000, MI_loss: 0.0574, total_loss: 1180.9659
# Epoch 160/200, elbo_loss: 1223.2065, kl_div_f: 3.4898, kl_div_z: 42.3296, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3848, entropy_loss: -46.5865, radial_variance: 0.7704, radius: 1.1432, L1_mu_z: 0.0000, MI_loss: 0.0586, total_loss: 1181.4619
# Epoch 161/200, elbo_loss: 1222.9319, kl_div_f: 3.4972, kl_div_z: 42.3374, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3882, entropy_loss: -46.1697, radial_variance: 0.7589, radius: 1.1506, L1_mu_z: 0.0000, MI_loss: 0.0610, total_loss: 1181.7237
# Epoch 162/200, elbo_loss: 1222.5876, kl_div_f: 3.5137, kl_div_z: 42.3364, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3902, entropy_loss: -45.7372, radial_variance: 0.7426, radius: 1.1230, L1_mu_z: 0.0000, MI_loss: 0.0600, total_loss: 1181.7154
# Epoch 163/200, elbo_loss: 1223.4855, kl_div_f: 3.5059, kl_div_z: 42.3362, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3788, entropy_loss: -45.1292, radial_variance: 0.8380, radius: 1.1811, L1_mu_z: 0.0000, MI_loss: 0.0551, total_loss: 1183.1308
# Epoch 164/200, elbo_loss: 1223.6860, kl_div_f: 3.4840, kl_div_z: 42.3374, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3839, entropy_loss: -44.7485, radial_variance: 0.8762, radius: 1.2095, L1_mu_z: 0.0000, MI_loss: 0.0546, total_loss: 1183.7543
# Epoch 165/200, elbo_loss: 1222.2309, kl_div_f: 3.4959, kl_div_z: 42.3343, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3904, entropy_loss: -44.3879, radial_variance: 0.7348, radius: 1.1162, L1_mu_z: 0.0000, MI_loss: 0.0605, total_loss: 1182.7175
# Epoch 166/200, elbo_loss: 1222.2223, kl_div_f: 3.5137, kl_div_z: 42.3346, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3903, entropy_loss: -43.9452, radial_variance: 0.7271, radius: 1.1415, L1_mu_z: 0.0000, MI_loss: 0.0571, total_loss: 1183.0011
# Epoch 167/200, elbo_loss: 1223.1394, kl_div_f: 3.5029, kl_div_z: 42.3310, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3781, entropy_loss: -43.3515, radial_variance: 0.8322, radius: 1.1607, L1_mu_z: 0.0000, MI_loss: 0.0547, total_loss: 1184.5169
# Epoch 168/200, elbo_loss: 1221.7784, kl_div_f: 3.4723, kl_div_z: 42.3408, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3891, entropy_loss: -43.0602, radial_variance: 0.7431, radius: 1.0900, L1_mu_z: 0.0000, MI_loss: 0.0629, total_loss: 1183.6948
# Epoch 169/200, elbo_loss: 1222.2897, kl_div_f: 3.4787, kl_div_z: 42.3380, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3842, entropy_loss: -42.5693, radial_variance: 0.7665, radius: 1.1509, L1_mu_z: 0.0000, MI_loss: 0.0491, total_loss: 1184.0944
# Epoch 170/200, elbo_loss: 1221.9301, kl_div_f: 3.4908, kl_div_z: 42.3323, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3847, entropy_loss: -42.1524, radial_variance: 0.7359, radius: 1.1278, L1_mu_z: 0.0000, MI_loss: 0.0564, total_loss: 1184.4615
# Epoch 171/200, elbo_loss: 1221.3173, kl_div_f: 3.5683, kl_div_z: 42.3436, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3910, entropy_loss: -41.8106, radial_variance: 0.7412, radius: 1.0746, L1_mu_z: 0.0000, MI_loss: 0.0647, total_loss: 1184.5562
# Epoch 172/200, elbo_loss: 1221.5000, kl_div_f: 3.5982, kl_div_z: 42.3343, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3890, entropy_loss: -41.3697, radial_variance: 0.7393, radius: 1.1252, L1_mu_z: 0.0000, MI_loss: 0.0591, total_loss: 1184.9496
# Epoch 173/200, elbo_loss: 1221.2445, kl_div_f: 3.5764, kl_div_z: 42.3341, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3901, entropy_loss: -40.9720, radial_variance: 0.7296, radius: 1.1074, L1_mu_z: 0.0000, MI_loss: 0.0565, total_loss: 1184.9333
# Epoch 174/200, elbo_loss: 1221.1729, kl_div_f: 3.5158, kl_div_z: 42.3452, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3903, entropy_loss: -40.5666, radial_variance: 0.7388, radius: 1.1051, L1_mu_z: 0.0000, MI_loss: 0.0603, total_loss: 1185.4672
# Epoch 175/200, elbo_loss: 1221.0798, kl_div_f: 3.5111, kl_div_z: 42.3490, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3891, entropy_loss: -40.1489, radial_variance: 0.7572, radius: 1.0808, L1_mu_z: 0.0000, MI_loss: 0.0524, total_loss: 1185.3875
# Epoch 176/200, elbo_loss: 1220.8023, kl_div_f: 3.5175, kl_div_z: 42.3506, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3904, entropy_loss: -39.7641, radial_variance: 0.7281, radius: 1.0887, L1_mu_z: 0.0000, MI_loss: 0.0583, total_loss: 1185.7703
# Epoch 177/200, elbo_loss: 1221.4864, kl_div_f: 3.5313, kl_div_z: 42.3489, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3841, entropy_loss: -39.2950, radial_variance: 0.7995, radius: 1.1370, L1_mu_z: 0.0000, MI_loss: 0.0506, total_loss: 1186.6590
# Epoch 178/200, elbo_loss: 1220.3237, kl_div_f: 3.5182, kl_div_z: 42.3531, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3885, entropy_loss: -38.9550, radial_variance: 0.7312, radius: 1.0762, L1_mu_z: 0.0000, MI_loss: 0.0602, total_loss: 1186.1869
# Epoch 179/200, elbo_loss: 1220.5488, kl_div_f: 3.4916, kl_div_z: 42.3579, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3880, entropy_loss: -38.5622, radial_variance: 0.7312, radius: 1.1212, L1_mu_z: 0.0000, MI_loss: 0.0587, total_loss: 1186.7732
# Epoch 180/200, elbo_loss: 1220.5349, kl_div_f: 3.5184, kl_div_z: 42.3443, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3901, entropy_loss: -38.2013, radial_variance: 0.7698, radius: 1.1170, L1_mu_z: 0.0000, MI_loss: 0.0567, total_loss: 1187.0535
# Epoch 181/200, elbo_loss: 1220.8620, kl_div_f: 3.5465, kl_div_z: 42.3423, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3742, entropy_loss: -37.6440, radial_variance: 0.7929, radius: 1.1233, L1_mu_z: 0.0000, MI_loss: 0.0551, total_loss: 1187.8874
# Epoch 182/200, elbo_loss: 1220.7125, kl_div_f: 3.5786, kl_div_z: 42.3389, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3796, entropy_loss: -37.3293, radial_variance: 0.7795, radius: 1.1369, L1_mu_z: 0.0000, MI_loss: 0.0513, total_loss: 1187.8659
# Epoch 183/200, elbo_loss: 1221.6001, kl_div_f: 3.5724, kl_div_z: 42.3385, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3739, entropy_loss: -36.8960, radial_variance: 0.8614, radius: 1.1906, L1_mu_z: 0.0000, MI_loss: 0.0527, total_loss: 1189.3886
# Epoch 184/200, elbo_loss: 1221.6788, kl_div_f: 3.5144, kl_div_z: 42.3447, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3660, entropy_loss: -36.4426, radial_variance: 0.8697, radius: 1.1633, L1_mu_z: 0.0000, MI_loss: 0.0547, total_loss: 1190.0045
# Epoch 185/200, elbo_loss: 1220.3800, kl_div_f: 3.5745, kl_div_z: 42.3487, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3834, entropy_loss: -36.2666, radial_variance: 0.7779, radius: 1.1421, L1_mu_z: 0.0000, MI_loss: 0.0644, total_loss: 1189.2552
# Epoch 186/200, elbo_loss: 1220.3476, kl_div_f: 3.6125, kl_div_z: 42.3497, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3854, entropy_loss: -35.9276, radial_variance: 0.7669, radius: 1.1428, L1_mu_z: 0.0000, MI_loss: 0.0526, total_loss: 1188.9592
# Epoch 187/200, elbo_loss: 1219.6575, kl_div_f: 3.5720, kl_div_z: 42.3450, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3893, entropy_loss: -35.6110, radial_variance: 0.7230, radius: 1.1236, L1_mu_z: 0.0000, MI_loss: 0.0551, total_loss: 1188.6471
# Epoch 188/200, elbo_loss: 1219.4725, kl_div_f: 3.5033, kl_div_z: 42.3527, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3853, entropy_loss: -35.2148, radial_variance: 0.7313, radius: 1.1148, L1_mu_z: 0.0000, MI_loss: 0.0544, total_loss: 1188.8232
# Epoch 189/200, elbo_loss: 1219.3705, kl_div_f: 3.5281, kl_div_z: 42.3536, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3879, entropy_loss: -34.8909, radial_variance: 0.7567, radius: 1.0856, L1_mu_z: 0.0000, MI_loss: 0.0577, total_loss: 1189.2088
# Epoch 190/200, elbo_loss: 1220.0120, kl_div_f: 3.5244, kl_div_z: 42.3577, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3813, entropy_loss: -34.4764, radial_variance: 0.8124, radius: 1.1435, L1_mu_z: 0.0000, MI_loss: 0.0509, total_loss: 1190.0345
# Epoch 191/200, elbo_loss: 1218.8408, kl_div_f: 3.5251, kl_div_z: 42.3592, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3862, entropy_loss: -34.1826, radial_variance: 0.7424, radius: 1.0537, L1_mu_z: 0.0000, MI_loss: 0.0676, total_loss: 1189.8358
# Epoch 192/200, elbo_loss: 1220.0859, kl_div_f: 3.5323, kl_div_z: 42.3583, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3823, entropy_loss: -33.8036, radial_variance: 0.7768, radius: 1.1694, L1_mu_z: 0.0000, MI_loss: 0.0481, total_loss: 1190.6343
# Epoch 193/200, elbo_loss: 1222.0360, kl_div_f: 3.4848, kl_div_z: 42.3615, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3619, entropy_loss: -33.2654, radial_variance: 0.9513, radius: 1.2558, L1_mu_z: 0.0000, MI_loss: 0.0406, total_loss: 1193.0101
# Epoch 194/200, elbo_loss: 1218.9360, kl_div_f: 3.4700, kl_div_z: 42.3578, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3814, entropy_loss: -33.1255, radial_variance: 0.7913, radius: 1.0591, L1_mu_z: 0.0000, MI_loss: 0.0658, total_loss: 1190.9530
# Epoch 195/200, elbo_loss: 1218.9386, kl_div_f: 3.4904, kl_div_z: 42.3591, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3807, entropy_loss: -32.7896, radial_variance: 0.7572, radius: 1.0920, L1_mu_z: 0.0000, MI_loss: 0.0652, total_loss: 1191.2596
# Epoch 196/200, elbo_loss: 1218.5777, kl_div_f: 3.5417, kl_div_z: 42.3534, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3876, entropy_loss: -32.5294, radial_variance: 0.7143, radius: 1.1169, L1_mu_z: 0.0000, MI_loss: 0.0572, total_loss: 1190.7373
# Epoch 197/200, elbo_loss: 1218.2182, kl_div_f: 3.5276, kl_div_z: 42.3564, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3870, entropy_loss: -32.1998, radial_variance: 0.7094, radius: 1.0773, L1_mu_z: 0.0000, MI_loss: 0.0631, total_loss: 1190.9619
# Epoch 198/200, elbo_loss: 1218.3788, kl_div_f: 3.5263, kl_div_z: 42.3669, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3847, entropy_loss: -31.8582, radial_variance: 0.7332, radius: 1.0751, L1_mu_z: 0.0000, MI_loss: 0.0605, total_loss: 1191.3555
# Epoch 199/200, elbo_loss: 1218.2996, kl_div_f: 3.5424, kl_div_z: 42.3607, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3845, entropy_loss: -31.5391, radial_variance: 0.7276, radius: 1.1073, L1_mu_z: 0.0000, MI_loss: 0.0587, total_loss: 1191.5308
# Epoch 200/200, elbo_loss: 1217.8454, kl_div_f: 3.5377, kl_div_z: 42.3581, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3864, entropy_loss: -31.2429, radial_variance: 0.7135, radius: 1.0765, L1_mu_z: 0.0000, MI_loss: 0.0637, total_loss: 1191.5767

# %% [markdown]
# # Results Extraction and Analysis

# %%
# Get the infered theta values
model.to("cpu")
generative_outputs, space_outputs = model.get_outputs()
thetas = space_outputs["theta"].detach().numpy()
sns.histplot(thetas, bins=100)
# Out:
# <Axes: ylabel='Count'>

# %%
cells_projected = space_outputs["x_projected"].detach().numpy()
sns.histplot(
    x=cells_projected[:, 0],
    y=cells_projected[:, 1],
)
# Out:
# <Axes: >

# %% [markdown]
# ## Align Inferred Phases Using the G1/S Transition (setting origin and direction)

# %%
# thetas =
# plotting.modify_axis_labels()
# sns.histplot(thetas, bins=100)
thetas = model.infer_pseudotimes(adata, "spliced", True)
adata.obs["inferred_theta"] = thetas

# %% [markdown]
# ## Analyzing the Results

# %%
adata.obs["inferred_theta"] = thetas
utils.get_jensenshannon(adata=adata, pseudotime_column="inferred_theta", hue="S-phase")
# Out:
# 0.8224772013416933

# %%
plt.rcParams.update({"axes.titlesize": 18})
plt.rcParams.update({"legend.fontsize": 16})

# %%
sns.scatterplot(
    x=adata.obs["inferred_theta"],
    y=utils.normalize_angles(adata.obs["pca_theta"] - np.pi),
)
# Out:
# <Axes: xlabel='inferred_theta', ylabel='pca_theta'>

# %%
def add_theta(df, theta, theta_pca):
    df["inferred_theta"] = theta
    df["pca_theta"] = theta_pca
    return df


df_mean = pd.DataFrame(
    generative_outputs["px_rate"].detach().numpy(), columns=model.context_genes
)
df_mean = add_theta(df_mean, thetas, adata.obs["pca_theta"].values)
# df_rhythmic = pd.DataFrame(generative_outputs["rhythmic_term"].detach().numpy(), columns=model.rhythmic_gene_names)
df_rhythmic = pd.DataFrame(
    generative_outputs["F"].detach().numpy(), columns=model.context_genes
)
df_rhythmic = add_theta(df_rhythmic, thetas, adata.obs["pca_theta"].values)
df_z = pd.DataFrame(
    generative_outputs["Z"].detach().numpy(), columns=model.context_genes
)
df_z = add_theta(df_z, thetas, adata.obs["pca_theta"].values)

# %%
plotting.plot_cell_cycle(df_rhythmic)
# Out:
# /home/maxine/Documents/paychere/CoPhaser/src/CoPhaser/plotting.py:232: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels)

# %%
utils.add_histones_fraction(adata, layer="spliced", use_only_clustered=False)
plotting.plot_smoothed_size_evolution(
    adata, "inferred_theta", counts_sum_field="histones_fraction"
)

# %%
plotting.plot_model_decoded_space(
    df_rhythmic, "Fourier component of gene expression", gene_to_upper=False
)
# Out:
# /home/maxine/Documents/paychere/CoPhaser/src/CoPhaser/plotting.py:548: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[i].legend(loc="upper left", bbox_to_anchor=(1, 1))

# %%
library_size = adata_all_genes.layers[layer_to_use].sum(axis=1).A1

# %%
plotting.plot_gene_profile(
    df_mean,
    adata,
    layer_to_use="spliced",
    library_size=library_size,
    gene_to_upper=False,
)

# %% [markdown]
# Erythropoietic cells seem to have higher MKi67 transcripts throughout the cell cycle

# %%
fig, axs = plotting.modify_axis_labels()
sns.histplot(
    data=df_z, x="inferred_theta", y="Mki67", hue=adata.obs["Celltype"].values, ax=axs
)
axs.get_legend().remove()

# %%
gene = "Mki67"
fig, ax1 = plt.subplots()
sns.scatterplot(
    x=df_mean["inferred_theta"],
    y=adata[:, gene].layers[layer_to_use].toarray().flatten() / library_size,
    alpha=0.2,
    label="raw counts",
    ax=ax1,
    color="red",
).set(ylabel="Raw counts")
sns.scatterplot(
    x=df_mean["inferred_theta"].values,
    y=df_mean[gene].values / library_size,
    alpha=0.5,
    hue=adata.obs["Celltype"].values,
    ax=ax1,
    legend=False,
).set(ylabel="Inferred mean")
ax1.legend(loc="upper left")
ax1.set_xlabel("inferred theta")
ax1.set_ylabel("fraction of counts")
plt.title(gene)
plt.show()

# %%
adata.obs["celltype_cat"] = adata.obs["Celltype"].apply(
    lambda x: (
        "erythropoietic" if x == "Erythropoiesis (expansive, S-phase)" else "other"
    )
)

# %%
fix, ax = plt.subplots(figsize=(5, 6))
sns.barplot(
    x=adata.obs["celltype_cat"],
    y=adata[:, "Mki67"].layers["spliced"].todense().A1 / library_size,
    hue=adata.obs["S-phase"],
)
plt.xticks(fontsize=20)
# Out:
# ([0, 1], [Text(0, 0, 'other'), Text(1, 0, 'erythropoietic')])

# %%
plotting.plot_model_decoded_space(
    df_z, "Z component of gene expression", gene_to_upper=False
)
# Out:
# /home/maxine/Documents/paychere/CoPhaser/src/CoPhaser/plotting.py:548: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[i].legend(loc="upper left", bbox_to_anchor=(1, 1))

# %%
adata.obs["library_size"] = library_size

# %%
sns.scatterplot(
    x=utils.normalize_angles(adata.obs["pca_theta"] + np.pi),
    y=adata[:, "Top2a"].layers[layer_to_use].toarray().flatten() / library_size,
    alpha=0.2,
    hue=adata.obs["S-phase"].values,
).set(ylabel="Raw counts")
plt.legend(title="S phase", labels=["True", "False"])
plt.xlabel("PCA theta")
plt.title("Top2a")
# Out:
# Text(0.5, 1.0, 'Top2a')

# %%
sns.scatterplot(
    x=df_mean["inferred_theta"],
    y=adata[:, "Top2a"].layers[layer_to_use].toarray().flatten() / library_size,
    hue=adata.obs["S-phase"].values,
    alpha=0.2,
).set(ylabel="fraction of counts")
plt.legend(title="S phase", labels=["True", "False"])
plt.title("TOP2a")
# Out:
# Text(0.5, 1.0, 'TOP2a')

# %%
sns.histplot(
    x=adata.obs["pca_theta"],
    hue=adata.obs["S-phase"].values,
    stat="density",
    common_norm=False,
)
# Out:
# <Axes: xlabel='pca_theta', ylabel='Density'>

# %%
plotting.modify_axis_labels()
sns.histplot(x=df_mean["inferred_theta"], hue=adata.obs["S-phase"].values, legend=False)
plt.legend(title="S phase", labels=["True", "False"])

# %% [markdown]
# ## z Space analysis

# %%
import umap

reducer = umap.UMAP()
embedding = reducer.fit_transform(space_outputs["z"].numpy())

# %%
_, _ = plt.subplots(figsize=(6, 6))
sns.scatterplot(
    x=embedding[:, 0],
    y=embedding[:, 1],
    hue=adata.obs["Celltype"],
    edgecolor=None,
    s=2,
    alpha=0.5,
    legend=False,
)
# Out:
# <Axes: >

# %%
plotting.plot_z_space(space_outputs["z"], adata.obs["Stage"], adata.obs["S-phase"])

# %%
utils.get_jensenshannon(adata=adata, pseudotime_column="inferred_theta", hue="S-phase")
# Out:
# 0.8224772013416933

# %%
utils.get_jensenshannon(adata=adata, pseudotime_column="pca_theta", hue="S-phase")
# Out:
# 0.2960033872640497

# %%
# utils.get_jensenshannon(adata=adata,pseudotime_column="posterior_theta",hue="S-phase")

# %%
adata.obs["random\ntheta"] = np.random.uniform(-np.pi, np.pi, len(adata.obs))
utils.get_jensenshannon(adata=adata, pseudotime_column="random\ntheta", hue="S-phase")
# Out:
# 0.029425546337095574

# %%
JS_res = {  # "posterior\n decoder":[utils.get_jensenshannon(adata=adata,pseudotime_column="posterior_theta",hue="S-phase")],
    "Our Method": [
        utils.get_jensenshannon(
            adata=adata, pseudotime_column="inferred_theta", hue="S-phase"
        )
    ],
    "PCA": [
        utils.get_jensenshannon(
            adata=adata, pseudotime_column="pca_theta", hue="S-phase"
        )
    ],
    # "PCA": [
    #     utils.get_jensenshannon(
    #         adata=adata, pseudotime_column="pca_theta", hue="S-phase"
    #     )
    # ],
    "Cyclop": [0.12634239067230416],
    "random": utils.get_jensenshannon(
        adata=adata, pseudotime_column="random\ntheta", hue="S-phase"
    ),
}

# %%
adata.obs["Celltype"] = adata.obs["Celltype"].astype(str)

# %%
# to_save = {
#     "embedding": embedding,
#     "phases": adata.obs["inferred_theta"],
#     "author_labels": adata.obs["S-phase"],
#     "JS_res": JS_res,
#     "f_space": cells_projected,
#     "df_rhythmic": df_rhythmic,
#     "df_mean": df_mean,
#     "df_z": df_z,
# }
# import pickle

# # with open("../data/vasa_res.pkl", "wb") as f:
# #     pickle.dump(to_save, f)

# %%
plt.subplots(figsize=(7.5, 7))
sns.barplot(pd.DataFrame(JS_res))
plt.xticks(fontsize=18)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Our Method'),
#   Text(1, 0, 'PCA'),
#   Text(2, 0, 'Cyclop'),
#   Text(3, 0, 'random')])

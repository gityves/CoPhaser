# %% [markdown]
# data from [single-cell RNA expression atlas of normal, preneoplastic and tumorigenic states in the human breast](https://doi.org/10.15252/embj.2020107333)

# %%
import numpy as np
import os
from cophaser import utils
from cophaser.trainer import Trainer
from cophaser.loss import Loss
from cophaser import plotting
from cophaser.model import CoPhaser
from cophaser import gene_sets


import torch
import matplotlib.pyplot as plt
import seaborn as sns
from importlib import resources

import anndata
import scanpy as sc

import pandas as pd

# %%
# %load_ext autoreload
# %autoreload 2

# %%
DATA_FOLDER = "../../../data/"
adata = anndata.read_h5ad(f"{DATA_FOLDER}breast_cancer_2021/processed_data/TNBC.h5ad")
adata_her2 = anndata.read_h5ad(
    f"{DATA_FOLDER}breast_cancer_2021/processed_data/HER2.h5ad"
)
adata_ERTotal = anndata.read_h5ad(
    f"{DATA_FOLDER}breast_cancer_2021/processed_data/ERTotal.h5ad"
)
# adata = anndata.read_h5ad("../data/cellcycle_maxine/different_cell_types/phase_VASA.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 54820 × 24867
#     obs: 'orig_file', 'group', 'n_counts', 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'integrated_snn_res.0.1', 'seurat_clusters'

# %%
adata.var_names
# Out:
# Index(['A1BG', 'A1BG-AS1', 'A2M', 'A2M-AS1', 'A2ML1', 'A4GALT', 'AAAS', 'AACS',
#        'AADAC', 'AADACL2-AS1',
#        ...
#        'ZW10', 'ZWILCH', 'ZWINT', 'ZXDA', 'ZXDB', 'ZXDC', 'ZYG11A', 'ZYG11B',
#        'ZYX', 'ZZEF1'],
#       dtype='object', length=24867)

# %%
adata.obs["group"].unique()
# Out:
# ['TN_B1_0131', 'TN_0114_T2', 'TN_0106', 'TN_B1_4031', 'TN_B1_0177', 'TN_0135', 'TN_0126', 'TN_B1_0554']
# Categories (8, object): ['TN_0106', 'TN_0114_T2', 'TN_0126', 'TN_0135', 'TN_B1_0131', 'TN_B1_0177', 'TN_B1_0554', 'TN_B1_4031']

# %%
adata.obs["cancer_type"] = "TNBC"
adata_her2.obs["cancer_type"] = "HER2+"
adata_ERTotal.obs["cancer_type"] = "ER"

# %%
not_cycling = anndata.concat(
    [
        adata[adata.obs["seurat_clusters"].apply(lambda x: x in [0])].copy(),
        adata_her2[adata_her2.obs["seurat_clusters"].apply(lambda x: x in [0])].copy(),
        adata_ERTotal[
            adata_ERTotal.obs["seurat_clusters"].apply(lambda x: x in [0])
        ].copy(),
    ]
)

# %%
not_cycling.obs
# Out:
#                                              orig_file       group  n_counts  \
# TN_B1_0131_AAACCTGCACATGTGT-1  GSM4909286_TN-B1-MH0131  TN_B1_0131   21404.0
# TN_B1_0131_AAACCTGCAGCTTCGG-1  GSM4909286_TN-B1-MH0131  TN_B1_0131    4175.0
# TN_B1_0131_AAACCTGGTCATGCAT-1  GSM4909286_TN-B1-MH0131  TN_B1_0131    7444.0
# TN_B1_0131_AAACCTGGTGACCAAG-1  GSM4909286_TN-B1-MH0131  TN_B1_0131   33822.0
# TN_B1_0131_AAACCTGGTTAAGAAC-1  GSM4909286_TN-B1-MH0131  TN_B1_0131   41062.0
# ...                                                ...         ...       ...
# ER_0167_T_TTTGTTGCAAAGACTA-1    GSM4909315_ER-MH0167-T   ER_0167_T    5903.0
# ER_0167_T_TTTGTTGGTGACTCGC-1    GSM4909315_ER-MH0167-T   ER_0167_T    4389.0
# ER_0167_T_TTTGTTGGTTCTATCT-1    GSM4909315_ER-MH0167-T   ER_0167_T    4326.0
# ER_0167_T_TTTGTTGTCGCAATTG-1    GSM4909315_ER-MH0167-T   ER_0167_T   13518.0
# ER_0167_T_TTTGTTGTCGCCGAGT-1    GSM4909315_ER-MH0167-T   ER_0167_T   33771.0
#
#                               orig.ident  nCount_RNA  nFeature_RNA  \
# TN_B1_0131_AAACCTGCACATGTGT-1         TN     18718.0        3255.0
# TN_B1_0131_AAACCTGCAGCTTCGG-1         TN      3495.0        1320.0
# TN_B1_0131_AAACCTGGTCATGCAT-1         TN      6704.0        1732.0
# TN_B1_0131_AAACCTGGTGACCAAG-1         TN     30297.0        4420.0
# TN_B1_0131_AAACCTGGTTAAGAAC-1         TN     34238.0        4623.0
# ...                                  ...         ...           ...
# ER_0167_T_TTTGTTGCAAAGACTA-1          ER      5857.0        1739.0
# ER_0167_T_TTTGTTGGTGACTCGC-1          ER      4019.0        1734.0
# ER_0167_T_TTTGTTGGTTCTATCT-1          ER      4187.0        1979.0
# ER_0167_T_TTTGTTGTCGCAATTG-1          ER     13126.0        2815.0
# ER_0167_T_TTTGTTGTCGCCGAGT-1          ER     30268.0        4706.0
#
#                                seurat_clusters cancer_type
# TN_B1_0131_AAACCTGCACATGTGT-1              0.0        TNBC
# TN_B1_0131_AAACCTGCAGCTTCGG-1              0.0        TNBC
# TN_B1_0131_AAACCTGGTCATGCAT-1              0.0        TNBC
# TN_B1_0131_AAACCTGGTGACCAAG-1              0.0        TNBC
# TN_B1_0131_AAACCTGGTTAAGAAC-1              0.0        TNBC
# ...                                        ...         ...
# ER_0167_T_TTTGTTGCAAAGACTA-1               0.0          ER
# ER_0167_T_TTTGTTGGTGACTCGC-1               0.0          ER
# ER_0167_T_TTTGTTGGTTCTATCT-1               0.0          ER
# ER_0167_T_TTTGTTGTCGCAATTG-1               0.0          ER
# ER_0167_T_TTTGTTGTCGCCGAGT-1               0.0          ER
#
# [69879 rows x 8 columns]

# %%
adata = adata[
    adata.obs["seurat_clusters"].apply(lambda x: x in [2])
].copy()  # select epi cells in cell cycle, based on fig 6 and EV2, https://doi.org/10.15252/embj.2020107333
adata_her2 = adata_her2[
    adata_her2.obs["seurat_clusters"].apply(lambda x: x in [3])
].copy()
adata_ERTotal = adata_ERTotal[
    adata_ERTotal.obs["seurat_clusters"].apply(lambda x: x in [4])
].copy()

# %%
adata = anndata.concat([adata, adata_her2, adata_ERTotal], join="outer")

# %%
adata.obs["cycling"] = True
not_cycling.obs["cycling"] = False

# %%
adata = anndata.concat([adata, not_cycling])

# %%
adata.obs["group"].unique()
# Out:
# ['TN_B1_0131', 'TN_0114_T2', 'TN_0106', 'TN_B1_4031', 'TN_B1_0177', ..., 'ER_0042', 'ER_0319', 'ER_0360', 'ER_0151', 'ER_0167_T']
# Length: 27
# Categories (27, object): ['ER_0001', 'ER_0025', 'ER_0032', 'ER_0040_T', ..., 'TN_B1_0131', 'TN_B1_0177', 'TN_B1_0554', 'TN_B1_4031']

# %%
adata_all_genes = adata.copy()
library_size = adata_all_genes.X.sum(axis=1).A1
adata.layers["raw"] = adata.X.copy()
utils.add_histones_fraction(adata=adata, layer="raw")

# %%
SMALL_CYCLING_GENE_SET = gene_sets.SMALL_CELL_CYCLE_GENE_SET
SMALL_CYCLING_GENE_SET = [g.upper() for g in SMALL_CYCLING_GENE_SET]
adata = adata[:, adata.var_names.isin(SMALL_CYCLING_GENE_SET)]

# %%
adata
# Out:
# View of AnnData object with n_obs × n_vars = 85542 × 98
#     obs: 'orig_file', 'group', 'n_counts', 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'seurat_clusters', 'cancer_type', 'cycling', 'histones_fraction'
#     layers: 'raw'

# %%
# mean center the adata
adata.X = adata.X - adata.X.mean(axis=1)
# Out:
# /tmp/ipykernel_372464/1782500935.py:2: ImplicitModificationWarning: X should not be a np.matrix, use np.ndarray instead.
#   adata.X = adata.X - adata.X.mean(axis=1)
# /home/maxine/miniconda3/envs/CoPhaser_Env/lib/python3.13/site-packages/anndata/_core/anndata.py:636: FutureWarning: You are attempting to set `X` to a matrix on a view which has non-unique indices. The resulting `adata.X` will likely not equal the value to which you set it. To avoid this potential issue, please make a copy of the data first. In the future, this operation will throw an error.
#   warnings.warn(msg, FutureWarning, stacklevel=1)
# /tmp/ipykernel_372464/1782500935.py:2: ImplicitModificationWarning: Modifying `X` on a view results in data being overridden
#   adata.X = adata.X - adata.X.mean(axis=1)
# /home/maxine/miniconda3/envs/CoPhaser_Env/lib/python3.13/site-packages/scipy/sparse/_index.py:201: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_arrayXarray_sparse(i, j, x)

# %%
# pca on the data
sc.pp.pca(adata)
# plot the pca
sc.pl.pca(adata, components="2,3")
# Out:
# /home/maxine/miniconda3/envs/CoPhaser_Env/lib/python3.13/site-packages/scanpy/preprocessing/_pca/__init__.py:384: ImplicitModificationWarning: Setting element `.obsm['X_pca']` of view, initializing view as actual.
#   adata.obsm[key_obsm] = x_pca

# %%
sc.pl.pca(adata, components="1,3")

# %%
adata.obs["pca_theta"] = np.arctan2(
    adata.obsm["X_pca"][:, 3], adata.obsm["X_pca"][:, 2]
)
plotting.plot_smoothed_size_evolution(
    adata,
    "pca_theta",
    counts_sum_field="histones_fraction",
    hue="cancer_type",
)

# %%
# add PCA theta to adata.obs
adata.obs["pca_theta"] = np.arctan2(
    adata.obsm["X_pca"][:, 1], adata.obsm["X_pca"][:, 0]
)
adata_all_genes.obs["pca_theta"] = adata.obs["pca_theta"].copy()
adata = adata_all_genes.copy()

# %%
adata.obs["pca_theta"].plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
adata = adata_all_genes.copy()

# %%
adata.layers["total"] = adata.X

# %%
g = utils.get_variable_genes(adata, 2000, layer="total")
len(g)
# Out:
# 2000

# %%
adata.obs["group"].nunique()
# Out:
# 27

# %%
SMALL_CYCLING_GENE_SET = np.array(
    list(set(SMALL_CYCLING_GENE_SET) & set(adata.var_names))
)

# %%
model = CoPhaser(
    SMALL_CYCLING_GENE_SET,
    g,
    n_latent=10,
    n_harm=3,
    use_mu_z_encoder=True,
    z_range=20,
    rhythmic_z_scale=2,
    lambda_range=1,
)  # , categorical_covariate_dims=[27])
model.load_anndata(
    adata, layer_to_use="total"
)  # , batch_name="cancer_type")#,categorical_covariates=["group"])

# %%
f_coeffs_path = (
    resources.files("cophaser") / "resources" / "fourier_coefficients_RPE.csv"
)
f_coeffs = pd.read_csv(f_coeffs_path, index_col=0)
f_coeffs.drop("A_0", axis=1, inplace=True)
f_coeffs = f_coeffs.loc[model.rhythmic_gene_names].copy()
old_weights = model.rhythmic_decoder.fourier_coefficients.weight.detach().clone()
old_weights[model.rhythmic_gene_indices, :] = torch.tensor(f_coeffs.values).float()
old_weights = torch.nn.Parameter(old_weights)
model.rhythmic_decoder.fourier_coefficients.weight = old_weights
model.rhythmic_decoder.freeze_weights_genes(model.rhythmic_gene_indices)

# %%
model.plot_fourier_coefficients()

# %%
trainer = Trainer(
    model,
    Loss.compute_loss,
    calculate_entropy_per_batch=False,
    L2_Z_decoder_loss_weight=0,
    entropy_weight_factor=100,
    closed_circle_weight=10,
    MI_weight=100,
    cycling_status_prior=0.1,
    beta_kl_cycling_status=20,
    unfreeze_epoch_layer=[(20, "rhythmic_decoder")],
    rhythmic_likelihood_weight=20,
    non_rhythmic_likelihood_weight=5,
)  # , entropy_weight_factor=5)
trainer.train_model(
    subsample=None,
    n_epochs=200,
    lr=1e-2,
    device="cuda",
    batch_size=4096,
)
# Out:
# Epoch 1/200, elbo_loss: 4069.3214, kl_div_f: 4.6779, kl_div_z: 33.9691, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.1793, entropy_loss: -317.9307, radial_variance: 4.3440, radius: 5.8392, L1_mu_z: 0.0000, MI_loss: 0.0000, total_loss: 3761.5740
# Epoch 2/200, elbo_loss: 3379.5548, kl_div_f: 4.6213, kl_div_z: 39.5843, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.2987, entropy_loss: -329.8676, radial_variance: 2.4623, radius: 4.2111, L1_mu_z: 0.0000, MI_loss: 0.0044, total_loss: 3056.8016
# Epoch 3/200, elbo_loss: 3161.2368, kl_div_f: 4.5642, kl_div_z: 39.0684, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3702, entropy_loss: -337.0245, radial_variance: 1.2926, radius: 5.2877, L1_mu_z: 0.0000, MI_loss: 0.0189, total_loss: 2832.6863
# Epoch 4/200, elbo_loss: 3043.7763, kl_div_f: 4.5032, kl_div_z: 39.5092, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3866, entropy_loss: -338.6565, radial_variance: 1.4017, radius: 5.4572, L1_mu_z: 0.0000, MI_loss: 0.0371, total_loss: 2715.6897
# Epoch 5/200, elbo_loss: 2971.9457, kl_div_f: 4.4460, kl_div_z: 38.9855, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3926, entropy_loss: -339.2560, radial_variance: 1.2385, radius: 5.7068, L1_mu_z: 0.0000, MI_loss: 0.0553, total_loss: 2645.1652
# Epoch 6/200, elbo_loss: 2922.3328, kl_div_f: 4.3892, kl_div_z: 40.6121, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3935, entropy_loss: -339.3515, radial_variance: 1.1688, radius: 5.9090, L1_mu_z: 0.0000, MI_loss: 0.0740, total_loss: 2597.4558
# Epoch 7/200, elbo_loss: 2890.1933, kl_div_f: 4.3353, kl_div_z: 43.0114, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3941, entropy_loss: -339.4094, radial_variance: 1.2076, radius: 5.8833, L1_mu_z: 0.0000, MI_loss: 0.0886, total_loss: 2566.7387
# Epoch 8/200, elbo_loss: 2860.1934, kl_div_f: 4.2885, kl_div_z: 42.5199, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3947, entropy_loss: -339.4706, radial_variance: 1.1543, radius: 5.8539, L1_mu_z: 0.0000, MI_loss: 0.0997, total_loss: 2537.7016
# Epoch 9/200, elbo_loss: 2837.3796, kl_div_f: 4.2330, kl_div_z: 41.5080, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3957, entropy_loss: -339.5653, radial_variance: 1.2262, radius: 5.7572, L1_mu_z: 0.0000, MI_loss: 0.1094, total_loss: 2515.7362
# Epoch 10/200, elbo_loss: 2820.0328, kl_div_f: 4.1848, kl_div_z: 40.8110, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3949, entropy_loss: -339.4938, radial_variance: 1.1740, radius: 5.7716, L1_mu_z: 0.0000, MI_loss: 0.1225, total_loss: 2499.7298
# Epoch 11/200, elbo_loss: 2805.8009, kl_div_f: 4.1335, kl_div_z: 40.0072, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3971, entropy_loss: -339.7091, radial_variance: 1.1114, radius: 5.7413, L1_mu_z: 0.0000, MI_loss: 0.1345, total_loss: 2486.3987
# Epoch 12/200, elbo_loss: 2871.1442, kl_div_f: 4.0839, kl_div_z: 41.5202, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3851, entropy_loss: -338.5090, radial_variance: 1.4509, radius: 5.4170, L1_mu_z: 0.0000, MI_loss: 0.1267, total_loss: 2552.1697
# Epoch 13/200, elbo_loss: 2809.5349, kl_div_f: 4.0316, kl_div_z: 41.6147, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3970, entropy_loss: -339.6953, radial_variance: 1.1225, radius: 5.3749, L1_mu_z: 0.0000, MI_loss: 0.1517, total_loss: 2491.5097
# Epoch 14/200, elbo_loss: 2795.2963, kl_div_f: 3.9867, kl_div_z: 42.0280, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3982, entropy_loss: -339.8189, radial_variance: 1.2199, radius: 5.2019, L1_mu_z: 0.0000, MI_loss: 0.1506, total_loss: 2476.9616
# Epoch 15/200, elbo_loss: 2785.8418, kl_div_f: 3.9467, kl_div_z: 41.7076, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3984, entropy_loss: -339.8446, radial_variance: 1.1245, radius: 5.2178, L1_mu_z: 0.0000, MI_loss: 0.1537, total_loss: 2467.7073
# Epoch 16/200, elbo_loss: 2780.7383, kl_div_f: 3.9107, kl_div_z: 41.3455, fraction_cycling_cells: 1.0000, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3990, entropy_loss: -339.8955, radial_variance: 1.1651, radius: 5.1404, L1_mu_z: 0.0000, MI_loss: 0.1515, total_loss: 2462.2959
# Epoch 17/200, elbo_loss: 2815.0630, kl_div_f: 4.1024, kl_div_z: 42.1097, fraction_cycling_cells: 0.2930, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3589, entropy_loss: -335.8870, radial_variance: 1.9114, radius: 2.6855, L1_mu_z: 0.0000, MI_loss: -0.0185, total_loss: 2481.9239
# Epoch 18/200, elbo_loss: 2804.2344, kl_div_f: 4.1204, kl_div_z: 43.2395, fraction_cycling_cells: 0.3011, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3833, entropy_loss: -338.3326, radial_variance: 1.1842, radius: 2.6104, L1_mu_z: 0.0000, MI_loss: -0.0011, total_loss: 2469.5855
# Epoch 19/200, elbo_loss: 2789.4974, kl_div_f: 4.1597, kl_div_z: 45.1216, fraction_cycling_cells: 0.2982, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3889, entropy_loss: -338.8881, radial_variance: 1.2554, radius: 2.4287, L1_mu_z: 0.0000, MI_loss: 0.0058, total_loss: 2454.8714
# Epoch 20/200, elbo_loss: 2794.1577, kl_div_f: 4.1572, kl_div_z: 46.9842, fraction_cycling_cells: 0.2953, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3903, entropy_loss: -339.0310, radial_variance: 1.2219, radius: 2.3835, L1_mu_z: 0.0000, MI_loss: -0.0013, total_loss: 2458.6052
# Epoch 21/200, elbo_loss: 2787.1896, kl_div_f: 4.1310, kl_div_z: 48.1381, fraction_cycling_cells: 0.3143, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3909, entropy_loss: -339.0898, radial_variance: 1.2291, radius: 2.5198, L1_mu_z: 0.0000, MI_loss: 0.0208, total_loss: 2453.9307
# Epoch 22/200, elbo_loss: 3206.6723, kl_div_f: 4.1755, kl_div_z: 49.3615, fraction_cycling_cells: 0.3029, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3243, entropy_loss: -332.4287, radial_variance: 1.6728, radius: 2.5439, L1_mu_z: 0.0000, MI_loss: -0.0656, total_loss: 2871.9041
# Epoch 23/200, elbo_loss: 3342.7549, kl_div_f: 4.1819, kl_div_z: 49.3760, fraction_cycling_cells: 0.2934, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.2651, entropy_loss: -326.5126, radial_variance: 2.0165, radius: 2.6285, L1_mu_z: 0.0000, MI_loss: -0.0675, total_loss: 3014.1349
# Epoch 24/200, elbo_loss: 3065.7849, kl_div_f: 4.1757, kl_div_z: 48.5375, fraction_cycling_cells: 0.2879, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.2681, entropy_loss: -326.8079, radial_variance: 1.9382, radius: 2.5309, L1_mu_z: 0.0000, MI_loss: -0.0498, total_loss: 2738.4694
# Epoch 25/200, elbo_loss: 2909.0155, kl_div_f: 4.1658, kl_div_z: 47.9468, fraction_cycling_cells: 0.2842, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.2972, entropy_loss: -329.7203, radial_variance: 1.7550, radius: 2.4044, L1_mu_z: 0.0000, MI_loss: -0.0246, total_loss: 2580.9933
# Epoch 26/200, elbo_loss: 2830.4768, kl_div_f: 4.1421, kl_div_z: 47.9711, fraction_cycling_cells: 0.2877, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3482, entropy_loss: -334.8207, radial_variance: 1.5478, radius: 2.3942, L1_mu_z: 0.0000, MI_loss: -0.0083, total_loss: 2498.7680
# Epoch 27/200, elbo_loss: 2792.7806, kl_div_f: 4.0878, kl_div_z: 48.2894, fraction_cycling_cells: 0.3065, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3855, entropy_loss: -338.5504, radial_variance: 1.3231, radius: 2.4959, L1_mu_z: 0.0000, MI_loss: 0.0325, total_loss: 2461.3012
# Epoch 28/200, elbo_loss: 2781.6838, kl_div_f: 4.0154, kl_div_z: 48.4930, fraction_cycling_cells: 0.3343, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3897, entropy_loss: -338.9720, radial_variance: 1.2144, radius: 2.6383, L1_mu_z: 0.0000, MI_loss: 0.1019, total_loss: 2456.7552
# Epoch 29/200, elbo_loss: 2777.8618, kl_div_f: 4.0076, kl_div_z: 48.6018, fraction_cycling_cells: 0.3328, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3908, entropy_loss: -339.0760, radial_variance: 1.2712, radius: 2.6666, L1_mu_z: 0.0000, MI_loss: 0.1097, total_loss: 2453.6934
# Epoch 30/200, elbo_loss: 2776.2430, kl_div_f: 4.0188, kl_div_z: 48.6227, fraction_cycling_cells: 0.3292, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3905, entropy_loss: -339.0495, radial_variance: 1.2553, radius: 2.6426, L1_mu_z: 0.0000, MI_loss: 0.0974, total_loss: 2450.8355
# Epoch 31/200, elbo_loss: 2775.2862, kl_div_f: 4.0103, kl_div_z: 48.6790, fraction_cycling_cells: 0.3334, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3904, entropy_loss: -339.0384, radial_variance: 1.2322, radius: 2.6601, L1_mu_z: 0.0000, MI_loss: 0.1156, total_loss: 2451.7031
# Epoch 32/200, elbo_loss: 2774.3988, kl_div_f: 4.0178, kl_div_z: 48.6973, fraction_cycling_cells: 0.3328, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3911, entropy_loss: -335.7399, radial_variance: 1.2516, radius: 2.6799, L1_mu_z: 0.0000, MI_loss: 0.1139, total_loss: 2453.9847
# Epoch 33/200, elbo_loss: 2774.2881, kl_div_f: 4.0316, kl_div_z: 48.7220, fraction_cycling_cells: 0.3293, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3897, entropy_loss: -332.2573, radial_variance: 1.2325, radius: 2.6543, L1_mu_z: 0.0000, MI_loss: 0.0947, total_loss: 2455.3892
# Epoch 34/200, elbo_loss: 2773.6331, kl_div_f: 4.0493, kl_div_z: 48.7360, fraction_cycling_cells: 0.3261, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3901, entropy_loss: -328.9917, radial_variance: 1.2178, radius: 2.6487, L1_mu_z: 0.0000, MI_loss: 0.1077, total_loss: 2459.2820
# Epoch 35/200, elbo_loss: 2773.3667, kl_div_f: 4.0700, kl_div_z: 48.7542, fraction_cycling_cells: 0.3247, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3909, entropy_loss: -325.7952, radial_variance: 1.2201, radius: 2.6369, L1_mu_z: 0.0000, MI_loss: 0.0797, total_loss: 2459.4000
# Epoch 36/200, elbo_loss: 2773.2424, kl_div_f: 4.0769, kl_div_z: 48.8150, fraction_cycling_cells: 0.3299, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3901, entropy_loss: -322.4799, radial_variance: 1.2013, radius: 2.6516, L1_mu_z: 0.0000, MI_loss: 0.0886, total_loss: 2463.4739
# Epoch 37/200, elbo_loss: 2772.5706, kl_div_f: 4.1059, kl_div_z: 48.8473, fraction_cycling_cells: 0.3286, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3907, entropy_loss: -319.3207, radial_variance: 1.2177, radius: 2.6543, L1_mu_z: 0.0000, MI_loss: 0.0740, total_loss: 2464.5266
# Epoch 38/200, elbo_loss: 2772.5901, kl_div_f: 4.1190, kl_div_z: 48.8846, fraction_cycling_cells: 0.3289, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3893, entropy_loss: -316.0195, radial_variance: 1.2066, radius: 2.6468, L1_mu_z: 0.0000, MI_loss: 0.0858, total_loss: 2469.0028
# Epoch 39/200, elbo_loss: 2771.9772, kl_div_f: 4.1484, kl_div_z: 48.9017, fraction_cycling_cells: 0.3270, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3907, entropy_loss: -313.0031, radial_variance: 1.2216, radius: 2.6443, L1_mu_z: 0.0000, MI_loss: 0.0684, total_loss: 2469.6754
# Epoch 40/200, elbo_loss: 2771.5425, kl_div_f: 4.1726, kl_div_z: 48.9495, fraction_cycling_cells: 0.3245, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3895, entropy_loss: -309.7763, radial_variance: 1.2130, radius: 2.6269, L1_mu_z: 0.0000, MI_loss: 0.0592, total_loss: 2471.5232
# Epoch 41/200, elbo_loss: 2771.4615, kl_div_f: 4.1768, kl_div_z: 49.0112, fraction_cycling_cells: 0.3327, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3889, entropy_loss: -306.6425, radial_variance: 1.2309, radius: 2.6893, L1_mu_z: 0.0000, MI_loss: 0.0814, total_loss: 2476.8748
# Epoch 42/200, elbo_loss: 2771.3291, kl_div_f: 4.2043, kl_div_z: 49.0629, fraction_cycling_cells: 0.3325, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3893, entropy_loss: -303.6244, radial_variance: 1.2128, radius: 2.6653, L1_mu_z: 0.0000, MI_loss: 0.0616, total_loss: 2477.7446
# Epoch 43/200, elbo_loss: 2770.9461, kl_div_f: 4.2142, kl_div_z: 49.1227, fraction_cycling_cells: 0.3368, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3889, entropy_loss: -300.5709, radial_variance: 1.2189, radius: 2.6979, L1_mu_z: 0.0000, MI_loss: 0.0618, total_loss: 2480.4719
# Epoch 44/200, elbo_loss: 2770.4562, kl_div_f: 4.2422, kl_div_z: 49.1593, fraction_cycling_cells: 0.3318, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3887, entropy_loss: -297.5626, radial_variance: 1.2286, radius: 2.6709, L1_mu_z: 0.0000, MI_loss: 0.0753, total_loss: 2484.3199
# Epoch 45/200, elbo_loss: 2770.3988, kl_div_f: 4.2668, kl_div_z: 49.2211, fraction_cycling_cells: 0.3319, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3889, entropy_loss: -294.6192, radial_variance: 1.2200, radius: 2.6756, L1_mu_z: 0.0000, MI_loss: 0.0678, total_loss: 2486.4508
# Epoch 46/200, elbo_loss: 2769.8421, kl_div_f: 4.2803, kl_div_z: 49.2290, fraction_cycling_cells: 0.3335, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3893, entropy_loss: -291.7191, radial_variance: 1.2188, radius: 2.6793, L1_mu_z: 0.0000, MI_loss: 0.0782, total_loss: 2489.8398
# Epoch 47/200, elbo_loss: 2769.3515, kl_div_f: 4.2914, kl_div_z: 49.3032, fraction_cycling_cells: 0.3357, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3882, entropy_loss: -288.7242, radial_variance: 1.2138, radius: 2.6972, L1_mu_z: 0.0000, MI_loss: 0.0740, total_loss: 2491.9390
# Epoch 48/200, elbo_loss: 2768.9169, kl_div_f: 4.2980, kl_div_z: 49.3858, fraction_cycling_cells: 0.3414, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3888, entropy_loss: -285.9004, radial_variance: 1.2379, radius: 2.7492, L1_mu_z: 0.0000, MI_loss: 0.0645, total_loss: 2493.4544
# Epoch 49/200, elbo_loss: 2768.6898, kl_div_f: 4.3094, kl_div_z: 49.4397, fraction_cycling_cells: 0.3375, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3884, entropy_loss: -283.0227, radial_variance: 1.2489, radius: 2.7398, L1_mu_z: 0.0000, MI_loss: 0.0757, total_loss: 2497.2261
# Epoch 50/200, elbo_loss: 2768.0591, kl_div_f: 4.3286, kl_div_z: 49.4975, fraction_cycling_cells: 0.3361, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3882, entropy_loss: -280.1901, radial_variance: 1.2250, radius: 2.7185, L1_mu_z: 0.0000, MI_loss: 0.0667, total_loss: 2498.4775
# Epoch 51/200, elbo_loss: 2768.0088, kl_div_f: 4.3361, kl_div_z: 49.5537, fraction_cycling_cells: 0.3422, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3869, entropy_loss: -277.2996, radial_variance: 1.2204, radius: 2.7591, L1_mu_z: 0.0000, MI_loss: 0.0884, total_loss: 2503.5265
# Epoch 52/200, elbo_loss: 2809.4132, kl_div_f: 4.6175, kl_div_z: 49.4553, fraction_cycling_cells: 0.3258, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.2744, entropy_loss: -265.4146, radial_variance: 9.4545, radius: 11.5779, L1_mu_z: 0.0000, MI_loss: -0.0826, total_loss: 2556.7708
# Epoch 53/200, elbo_loss: 2779.5805, kl_div_f: 4.7974, kl_div_z: 49.3885, fraction_cycling_cells: 0.2789, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3716, entropy_loss: -270.5809, radial_variance: 2.5224, radius: 2.7731, L1_mu_z: 0.0000, MI_loss: -0.0452, total_loss: 2509.7705
# Epoch 54/200, elbo_loss: 2774.6402, kl_div_f: 4.8285, kl_div_z: 49.3584, fraction_cycling_cells: 0.2918, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3833, entropy_loss: -268.8163, radial_variance: 1.4402, radius: 2.4910, L1_mu_z: 0.0000, MI_loss: -0.0039, total_loss: 2509.3693
# Epoch 55/200, elbo_loss: 2771.0914, kl_div_f: 4.8447, kl_div_z: 49.2715, fraction_cycling_cells: 0.2969, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3845, entropy_loss: -266.2364, radial_variance: 1.3203, radius: 2.5178, L1_mu_z: 0.0000, MI_loss: 0.0018, total_loss: 2508.8722
# Epoch 56/200, elbo_loss: 2770.1074, kl_div_f: 4.8630, kl_div_z: 49.2094, fraction_cycling_cells: 0.3073, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3889, entropy_loss: -263.9300, radial_variance: 1.2387, radius: 2.4918, L1_mu_z: 0.0000, MI_loss: 0.0445, total_loss: 2514.3583
# Epoch 57/200, elbo_loss: 2769.0395, kl_div_f: 4.8844, kl_div_z: 49.1183, fraction_cycling_cells: 0.2987, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3862, entropy_loss: -261.0953, radial_variance: 1.1722, radius: 2.5054, L1_mu_z: 0.0000, MI_loss: 0.0190, total_loss: 2513.5227
# Epoch 58/200, elbo_loss: 2768.2059, kl_div_f: 4.8909, kl_div_z: 49.0926, fraction_cycling_cells: 0.3016, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3880, entropy_loss: -258.6311, radial_variance: 1.2343, radius: 2.5013, L1_mu_z: 0.0000, MI_loss: 0.0403, total_loss: 2517.3414
# Epoch 59/200, elbo_loss: 2766.5802, kl_div_f: 4.8875, kl_div_z: 48.9965, fraction_cycling_cells: 0.3172, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3898, entropy_loss: -256.1928, radial_variance: 1.4146, radius: 2.5399, L1_mu_z: 0.0000, MI_loss: 0.0680, total_loss: 2521.1456
# Epoch 60/200, elbo_loss: 2765.3854, kl_div_f: 4.9144, kl_div_z: 48.8392, fraction_cycling_cells: 0.3159, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3883, entropy_loss: -253.5316, radial_variance: 1.1808, radius: 2.5519, L1_mu_z: 0.0000, MI_loss: 0.0692, total_loss: 2522.5094
# Epoch 61/200, elbo_loss: 2764.3483, kl_div_f: 4.8925, kl_div_z: 48.8039, fraction_cycling_cells: 0.3236, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3911, entropy_loss: -251.2223, radial_variance: 1.1206, radius: 2.6285, L1_mu_z: 0.0000, MI_loss: 0.0790, total_loss: 2524.7715
# Epoch 62/200, elbo_loss: 2763.7958, kl_div_f: 4.9075, kl_div_z: 48.8019, fraction_cycling_cells: 0.3212, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3913, entropy_loss: -248.7313, radial_variance: 1.1938, radius: 2.4482, L1_mu_z: 0.0000, MI_loss: 0.0744, total_loss: 2526.1428
# Epoch 63/200, elbo_loss: 2762.6985, kl_div_f: 4.8822, kl_div_z: 48.8089, fraction_cycling_cells: 0.3250, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3912, entropy_loss: -246.2502, radial_variance: 1.0970, radius: 2.5586, L1_mu_z: 0.0000, MI_loss: 0.0849, total_loss: 2528.5955
# Epoch 64/200, elbo_loss: 2762.7453, kl_div_f: 4.8724, kl_div_z: 48.8007, fraction_cycling_cells: 0.3289, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3903, entropy_loss: -243.7373, radial_variance: 1.1006, radius: 2.4515, L1_mu_z: 0.0000, MI_loss: 0.0805, total_loss: 2530.6148
# Epoch 65/200, elbo_loss: 2762.1481, kl_div_f: 4.8363, kl_div_z: 48.8021, fraction_cycling_cells: 0.3327, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3911, entropy_loss: -241.3695, radial_variance: 1.0682, radius: 2.5712, L1_mu_z: 0.0000, MI_loss: 0.0834, total_loss: 2532.7573
# Epoch 66/200, elbo_loss: 2761.4474, kl_div_f: 4.8297, kl_div_z: 48.7858, fraction_cycling_cells: 0.3343, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3900, entropy_loss: -238.8902, radial_variance: 1.0665, radius: 2.5236, L1_mu_z: 0.0000, MI_loss: 0.0886, total_loss: 2535.0107
# Epoch 67/200, elbo_loss: 2760.9295, kl_div_f: 4.7958, kl_div_z: 48.8180, fraction_cycling_cells: 0.3374, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3911, entropy_loss: -236.5920, radial_variance: 1.0674, radius: 2.4798, L1_mu_z: 0.0000, MI_loss: 0.0907, total_loss: 2536.9514
# Epoch 68/200, elbo_loss: 2760.6360, kl_div_f: 4.7777, kl_div_z: 48.8864, fraction_cycling_cells: 0.3372, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3900, entropy_loss: -234.1616, radial_variance: 1.0428, radius: 2.5106, L1_mu_z: 0.0000, MI_loss: 0.0769, total_loss: 2537.7209
# Epoch 69/200, elbo_loss: 2760.6413, kl_div_f: 4.7701, kl_div_z: 48.9530, fraction_cycling_cells: 0.3431, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3899, entropy_loss: -231.8251, radial_variance: 1.1426, radius: 2.5388, L1_mu_z: 0.0000, MI_loss: 0.0766, total_loss: 2540.1555
# Epoch 70/200, elbo_loss: 2759.9659, kl_div_f: 4.7453, kl_div_z: 48.9688, fraction_cycling_cells: 0.3478, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3903, entropy_loss: -229.5417, radial_variance: 1.0633, radius: 2.4947, L1_mu_z: 0.0000, MI_loss: 0.0981, total_loss: 2543.7880
# Epoch 71/200, elbo_loss: 2759.1684, kl_div_f: 4.7053, kl_div_z: 49.0198, fraction_cycling_cells: 0.3456, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3906, entropy_loss: -227.2804, radial_variance: 1.0164, radius: 2.5670, L1_mu_z: 0.0000, MI_loss: 0.0849, total_loss: 2543.9584
# Epoch 72/200, elbo_loss: 2758.7320, kl_div_f: 4.6895, kl_div_z: 49.0620, fraction_cycling_cells: 0.3524, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3892, entropy_loss: -224.9257, radial_variance: 1.0508, radius: 2.4930, L1_mu_z: 0.0000, MI_loss: 0.1011, total_loss: 2547.4633
# Epoch 73/200, elbo_loss: 2758.8626, kl_div_f: 4.6722, kl_div_z: 49.1578, fraction_cycling_cells: 0.3513, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3897, entropy_loss: -222.7214, radial_variance: 1.0811, radius: 2.4977, L1_mu_z: 0.0000, MI_loss: 0.0830, total_loss: 2548.0184
# Epoch 74/200, elbo_loss: 2758.7083, kl_div_f: 4.6666, kl_div_z: 49.2463, fraction_cycling_cells: 0.3517, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3898, entropy_loss: -220.5126, radial_variance: 1.1043, radius: 2.4634, L1_mu_z: 0.0000, MI_loss: 0.0815, total_loss: 2549.9135
# Epoch 75/200, elbo_loss: 2757.7465, kl_div_f: 4.6397, kl_div_z: 49.2889, fraction_cycling_cells: 0.3561, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3900, entropy_loss: -218.3277, radial_variance: 1.0455, radius: 2.4949, L1_mu_z: 0.0000, MI_loss: 0.0947, total_loss: 2552.4282
# Epoch 76/200, elbo_loss: 2757.4683, kl_div_f: 4.6417, kl_div_z: 49.3157, fraction_cycling_cells: 0.3592, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3889, entropy_loss: -216.0873, radial_variance: 1.0696, radius: 2.4177, L1_mu_z: 0.0000, MI_loss: 0.0904, total_loss: 2553.9105
# Epoch 77/200, elbo_loss: 2757.4046, kl_div_f: 4.6135, kl_div_z: 49.3983, fraction_cycling_cells: 0.3573, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3881, entropy_loss: -213.8843, radial_variance: 1.1092, radius: 2.4242, L1_mu_z: 0.0000, MI_loss: 0.0812, total_loss: 2555.1705
# Epoch 78/200, elbo_loss: 2757.4792, kl_div_f: 4.6125, kl_div_z: 49.4813, fraction_cycling_cells: 0.3596, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3882, entropy_loss: -211.7608, radial_variance: 1.1320, radius: 2.4711, L1_mu_z: 0.0000, MI_loss: 0.0929, total_loss: 2558.6158
# Epoch 79/200, elbo_loss: 2756.9170, kl_div_f: 4.6178, kl_div_z: 49.5316, fraction_cycling_cells: 0.3604, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3883, entropy_loss: -209.6649, radial_variance: 1.0989, radius: 2.4321, L1_mu_z: 0.0000, MI_loss: 0.0835, total_loss: 2559.1347
# Epoch 80/200, elbo_loss: 2756.6288, kl_div_f: 4.6008, kl_div_z: 49.6005, fraction_cycling_cells: 0.3614, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3884, entropy_loss: -207.5800, radial_variance: 1.0763, radius: 2.3858, L1_mu_z: 0.0000, MI_loss: 0.0974, total_loss: 2562.2480
# Epoch 81/200, elbo_loss: 2756.1063, kl_div_f: 4.5985, kl_div_z: 49.6295, fraction_cycling_cells: 0.3561, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3899, entropy_loss: -205.6055, radial_variance: 1.1053, radius: 2.3825, L1_mu_z: 0.0000, MI_loss: 0.0869, total_loss: 2562.6745
# Epoch 82/200, elbo_loss: 2755.9282, kl_div_f: 4.5989, kl_div_z: 49.6788, fraction_cycling_cells: 0.3595, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3888, entropy_loss: -203.4939, radial_variance: 1.0890, radius: 2.3343, L1_mu_z: 0.0000, MI_loss: 0.1148, total_loss: 2567.3417
# Epoch 83/200, elbo_loss: 2755.4829, kl_div_f: 4.5924, kl_div_z: 49.7244, fraction_cycling_cells: 0.3607, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3887, entropy_loss: -201.4644, radial_variance: 1.0721, radius: 2.3387, L1_mu_z: 0.0000, MI_loss: 0.0897, total_loss: 2566.3995
# Epoch 84/200, elbo_loss: 2755.5541, kl_div_f: 4.5911, kl_div_z: 49.8049, fraction_cycling_cells: 0.3605, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3882, entropy_loss: -199.4318, radial_variance: 1.1180, radius: 2.3562, L1_mu_z: 0.0000, MI_loss: 0.0808, total_loss: 2567.6754
# Epoch 85/200, elbo_loss: 2755.9066, kl_div_f: 4.5865, kl_div_z: 49.8773, fraction_cycling_cells: 0.3649, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3877, entropy_loss: -197.4186, radial_variance: 1.1043, radius: 2.3101, L1_mu_z: 0.0000, MI_loss: 0.1031, total_loss: 2572.2163
# Epoch 86/200, elbo_loss: 2754.9050, kl_div_f: 4.5856, kl_div_z: 49.8761, fraction_cycling_cells: 0.3634, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3886, entropy_loss: -195.5047, radial_variance: 1.0971, radius: 2.3119, L1_mu_z: 0.0000, MI_loss: 0.0896, total_loss: 2571.7719
# Epoch 87/200, elbo_loss: 2754.6623, kl_div_f: 4.5909, kl_div_z: 49.9166, fraction_cycling_cells: 0.3660, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3872, entropy_loss: -193.4798, radial_variance: 1.1278, radius: 2.3050, L1_mu_z: 0.0000, MI_loss: 0.0932, total_loss: 2573.9353
# Epoch 88/200, elbo_loss: 2754.0563, kl_div_f: 4.5791, kl_div_z: 49.9628, fraction_cycling_cells: 0.3666, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3884, entropy_loss: -191.6249, radial_variance: 1.0755, radius: 2.3275, L1_mu_z: 0.0000, MI_loss: 0.0952, total_loss: 2575.3585
# Epoch 89/200, elbo_loss: 2753.9090, kl_div_f: 4.5696, kl_div_z: 49.9600, fraction_cycling_cells: 0.3723, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3876, entropy_loss: -189.6687, radial_variance: 1.0862, radius: 2.2876, L1_mu_z: 0.0000, MI_loss: 0.0969, total_loss: 2577.3077
# Epoch 90/200, elbo_loss: 2753.3870, kl_div_f: 4.5684, kl_div_z: 49.9767, fraction_cycling_cells: 0.3685, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3879, entropy_loss: -187.8025, radial_variance: 1.0774, radius: 2.2414, L1_mu_z: 0.0000, MI_loss: 0.0970, total_loss: 2578.5988
# Epoch 91/200, elbo_loss: 2752.9573, kl_div_f: 4.5724, kl_div_z: 50.0023, fraction_cycling_cells: 0.3636, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3894, entropy_loss: -186.0150, radial_variance: 1.0782, radius: 2.2409, L1_mu_z: 0.0000, MI_loss: 0.0992, total_loss: 2580.1795
# Epoch 92/200, elbo_loss: 2752.5133, kl_div_f: 4.5661, kl_div_z: 50.0529, fraction_cycling_cells: 0.3626, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3881, entropy_loss: -184.0941, radial_variance: 1.0651, radius: 2.1872, L1_mu_z: 0.0000, MI_loss: 0.0974, total_loss: 2581.4070
# Epoch 93/200, elbo_loss: 2751.7678, kl_div_f: 4.5559, kl_div_z: 50.0192, fraction_cycling_cells: 0.3673, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3882, entropy_loss: -182.2646, radial_variance: 1.0795, radius: 2.2114, L1_mu_z: 0.0000, MI_loss: 0.1004, total_loss: 2582.8358
# Epoch 94/200, elbo_loss: 2751.3994, kl_div_f: 4.5642, kl_div_z: 50.0576, fraction_cycling_cells: 0.3648, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3883, entropy_loss: -180.4559, radial_variance: 1.0820, radius: 2.1766, L1_mu_z: 0.0000, MI_loss: 0.1013, total_loss: 2584.3317
# Epoch 95/200, elbo_loss: 2751.8235, kl_div_f: 4.5596, kl_div_z: 50.0437, fraction_cycling_cells: 0.3679, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3879, entropy_loss: -178.6401, radial_variance: 1.0891, radius: 2.1848, L1_mu_z: 0.0000, MI_loss: 0.0957, total_loss: 2586.0304
# Epoch 96/200, elbo_loss: 2751.1927, kl_div_f: 4.5599, kl_div_z: 50.0701, fraction_cycling_cells: 0.3701, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3881, entropy_loss: -176.8743, radial_variance: 1.1075, radius: 2.1870, L1_mu_z: 0.0000, MI_loss: 0.0853, total_loss: 2586.1441
# Epoch 97/200, elbo_loss: 2750.2961, kl_div_f: 4.5693, kl_div_z: 50.0262, fraction_cycling_cells: 0.3686, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3875, entropy_loss: -175.0821, radial_variance: 1.0636, radius: 2.1684, L1_mu_z: 0.0000, MI_loss: 0.1035, total_loss: 2588.7920
# Epoch 98/200, elbo_loss: 2750.1390, kl_div_f: 4.5763, kl_div_z: 49.9891, fraction_cycling_cells: 0.3654, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3881, entropy_loss: -173.3740, radial_variance: 1.0499, radius: 2.1421, L1_mu_z: 0.0000, MI_loss: 0.0868, total_loss: 2588.6393
# Epoch 99/200, elbo_loss: 2749.9001, kl_div_f: 4.5820, kl_div_z: 49.9689, fraction_cycling_cells: 0.3676, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3882, entropy_loss: -171.6524, radial_variance: 1.0726, radius: 2.0932, L1_mu_z: 0.0000, MI_loss: 0.1049, total_loss: 2591.9003
# Epoch 100/200, elbo_loss: 2749.9685, kl_div_f: 4.5803, kl_div_z: 49.9652, fraction_cycling_cells: 0.3695, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3876, entropy_loss: -169.9126, radial_variance: 1.0513, radius: 2.1076, L1_mu_z: 0.0000, MI_loss: 0.0950, total_loss: 2592.7149
# Epoch 101/200, elbo_loss: 2749.0736, kl_div_f: 4.5798, kl_div_z: 49.9394, fraction_cycling_cells: 0.3740, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3877, entropy_loss: -168.2295, radial_variance: 1.0666, radius: 2.1268, L1_mu_z: 0.0000, MI_loss: 0.0759, total_loss: 2591.6319
# Epoch 102/200, elbo_loss: 2749.6668, kl_div_f: 4.5896, kl_div_z: 49.9061, fraction_cycling_cells: 0.3708, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3878, entropy_loss: -166.5572, radial_variance: 1.1351, radius: 2.1059, L1_mu_z: 0.0000, MI_loss: 0.0909, total_loss: 2595.4437
# Epoch 103/200, elbo_loss: 2747.7343, kl_div_f: 4.5837, kl_div_z: 49.8459, fraction_cycling_cells: 0.3738, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3874, entropy_loss: -164.8832, radial_variance: 1.0596, radius: 2.1163, L1_mu_z: 0.0000, MI_loss: 0.0980, total_loss: 2595.8273
# Epoch 104/200, elbo_loss: 2747.5869, kl_div_f: 4.5849, kl_div_z: 49.7489, fraction_cycling_cells: 0.3719, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3875, entropy_loss: -163.2483, radial_variance: 1.0583, radius: 2.1315, L1_mu_z: 0.0000, MI_loss: 0.0862, total_loss: 2596.1529
# Epoch 105/200, elbo_loss: 2746.8109, kl_div_f: 4.5878, kl_div_z: 49.5813, fraction_cycling_cells: 0.3696, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3867, entropy_loss: -161.5863, radial_variance: 1.0647, radius: 2.0981, L1_mu_z: 0.0000, MI_loss: 0.0968, total_loss: 2598.0638
# Epoch 106/200, elbo_loss: 2746.4332, kl_div_f: 4.5909, kl_div_z: 49.0251, fraction_cycling_cells: 0.3715, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3859, entropy_loss: -159.9383, radial_variance: 1.0724, radius: 2.0754, L1_mu_z: 0.0000, MI_loss: 0.1091, total_loss: 2600.5530
# Epoch 107/200, elbo_loss: 2745.7034, kl_div_f: 4.5905, kl_div_z: 48.6600, fraction_cycling_cells: 0.3736, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3857, entropy_loss: -158.3388, radial_variance: 1.0647, radius: 2.0709, L1_mu_z: 0.0000, MI_loss: 0.0954, total_loss: 2600.0374
# Epoch 108/200, elbo_loss: 2745.0505, kl_div_f: 4.6019, kl_div_z: 48.6107, fraction_cycling_cells: 0.3724, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3867, entropy_loss: -156.8090, radial_variance: 1.0806, radius: 2.0431, L1_mu_z: 0.0000, MI_loss: 0.1078, total_loss: 2602.1488
# Epoch 109/200, elbo_loss: 2744.3474, kl_div_f: 4.6060, kl_div_z: 48.5531, fraction_cycling_cells: 0.3714, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3862, entropy_loss: -155.2263, radial_variance: 1.0316, radius: 2.0369, L1_mu_z: 0.0000, MI_loss: 0.1011, total_loss: 2602.3029
# Epoch 110/200, elbo_loss: 2743.9205, kl_div_f: 4.5983, kl_div_z: 48.4811, fraction_cycling_cells: 0.3730, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3864, entropy_loss: -153.6886, radial_variance: 1.0545, radius: 2.0343, L1_mu_z: 0.0000, MI_loss: 0.0989, total_loss: 2603.2148
# Epoch 111/200, elbo_loss: 2743.8487, kl_div_f: 4.6044, kl_div_z: 48.4607, fraction_cycling_cells: 0.3720, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3860, entropy_loss: -152.1406, radial_variance: 1.0602, radius: 2.0204, L1_mu_z: 0.0000, MI_loss: 0.1059, total_loss: 2605.3753
# Epoch 112/200, elbo_loss: 2743.2990, kl_div_f: 4.6119, kl_div_z: 48.4254, fraction_cycling_cells: 0.3730, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3859, entropy_loss: -150.6239, radial_variance: 1.0616, radius: 2.0022, L1_mu_z: 0.0000, MI_loss: 0.1027, total_loss: 2606.0133
# Epoch 113/200, elbo_loss: 2743.4018, kl_div_f: 4.6192, kl_div_z: 48.3781, fraction_cycling_cells: 0.3623, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3870, entropy_loss: -149.1731, radial_variance: 1.0443, radius: 1.9693, L1_mu_z: 0.0000, MI_loss: 0.0865, total_loss: 2605.8965
# Epoch 114/200, elbo_loss: 2742.7400, kl_div_f: 4.6049, kl_div_z: 48.3223, fraction_cycling_cells: 0.3771, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3842, entropy_loss: -147.5693, radial_variance: 1.0498, radius: 2.0099, L1_mu_z: 0.0000, MI_loss: 0.1155, total_loss: 2609.7793
# Epoch 115/200, elbo_loss: 2742.1687, kl_div_f: 4.6160, kl_div_z: 48.2291, fraction_cycling_cells: 0.3757, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3856, entropy_loss: -146.1598, radial_variance: 1.0444, radius: 1.9960, L1_mu_z: 0.0000, MI_loss: 0.1056, total_loss: 2609.6100
# Epoch 116/200, elbo_loss: 2741.7252, kl_div_f: 4.6257, kl_div_z: 48.2297, fraction_cycling_cells: 0.3702, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3872, entropy_loss: -144.7754, radial_variance: 1.0676, radius: 1.9692, L1_mu_z: 0.0000, MI_loss: 0.0904, total_loss: 2609.0265
# Epoch 117/200, elbo_loss: 2741.9805, kl_div_f: 4.6293, kl_div_z: 48.2123, fraction_cycling_cells: 0.3712, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3848, entropy_loss: -143.2307, radial_variance: 1.0376, radius: 2.0059, L1_mu_z: 0.0000, MI_loss: 0.0913, total_loss: 2610.9263
# Epoch 118/200, elbo_loss: 2741.3477, kl_div_f: 4.6326, kl_div_z: 48.2402, fraction_cycling_cells: 0.3731, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3848, entropy_loss: -141.8059, radial_variance: 1.0358, radius: 1.9394, L1_mu_z: 0.0000, MI_loss: 0.0967, total_loss: 2612.1855
# Epoch 119/200, elbo_loss: 2740.8121, kl_div_f: 4.6321, kl_div_z: 48.1764, fraction_cycling_cells: 0.3787, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3835, entropy_loss: -140.3424, radial_variance: 1.0530, radius: 1.9415, L1_mu_z: 0.0000, MI_loss: 0.1072, total_loss: 2614.1816
# Epoch 120/200, elbo_loss: 2740.4763, kl_div_f: 4.6349, kl_div_z: 48.1003, fraction_cycling_cells: 0.3768, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3839, entropy_loss: -138.9630, radial_variance: 1.0456, radius: 1.9351, L1_mu_z: 0.0000, MI_loss: 0.0961, total_loss: 2614.1021
# Epoch 121/200, elbo_loss: 2739.9482, kl_div_f: 4.6434, kl_div_z: 47.4282, fraction_cycling_cells: 0.3755, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3840, entropy_loss: -137.5838, radial_variance: 1.0427, radius: 1.9151, L1_mu_z: 0.0000, MI_loss: 0.0895, total_loss: 2614.2715
# Epoch 122/200, elbo_loss: 2739.8494, kl_div_f: 4.6432, kl_div_z: 47.1102, fraction_cycling_cells: 0.3708, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3859, entropy_loss: -136.2897, radial_variance: 1.0463, radius: 1.9219, L1_mu_z: 0.0000, MI_loss: 0.0895, total_loss: 2615.4769
# Epoch 123/200, elbo_loss: 2738.5846, kl_div_f: 4.6512, kl_div_z: 46.1671, fraction_cycling_cells: 0.3711, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3848, entropy_loss: -134.8899, radial_variance: 1.0252, radius: 1.8849, L1_mu_z: 0.0000, MI_loss: 0.1016, total_loss: 2616.7640
# Epoch 124/200, elbo_loss: 2738.1091, kl_div_f: 4.6481, kl_div_z: 45.6982, fraction_cycling_cells: 0.3747, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3851, entropy_loss: -133.5598, radial_variance: 1.0244, radius: 1.9193, L1_mu_z: 0.0000, MI_loss: 0.0951, total_loss: 2616.9997
# Epoch 125/200, elbo_loss: 2737.7805, kl_div_f: 4.6509, kl_div_z: 45.5752, fraction_cycling_cells: 0.3717, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3856, entropy_loss: -132.2516, radial_variance: 1.0344, radius: 1.8818, L1_mu_z: 0.0000, MI_loss: 0.1025, total_loss: 2618.6959
# Epoch 126/200, elbo_loss: 2737.2738, kl_div_f: 4.6583, kl_div_z: 45.4573, fraction_cycling_cells: 0.3769, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3840, entropy_loss: -130.8714, radial_variance: 1.0527, radius: 1.8689, L1_mu_z: 0.0000, MI_loss: 0.1073, total_loss: 2620.0510
# Epoch 127/200, elbo_loss: 2736.8640, kl_div_f: 4.6581, kl_div_z: 45.4855, fraction_cycling_cells: 0.3755, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3841, entropy_loss: -129.5738, radial_variance: 1.0272, radius: 1.9049, L1_mu_z: 0.0000, MI_loss: 0.0991, total_loss: 2620.1283
# Epoch 128/200, elbo_loss: 2736.6318, kl_div_f: 4.6520, kl_div_z: 45.5247, fraction_cycling_cells: 0.3764, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3834, entropy_loss: -128.2572, radial_variance: 0.9947, radius: 1.9016, L1_mu_z: 0.0000, MI_loss: 0.0997, total_loss: 2621.2367
# Epoch 129/200, elbo_loss: 2736.1501, kl_div_f: 4.6564, kl_div_z: 45.4177, fraction_cycling_cells: 0.3777, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3837, entropy_loss: -126.9948, radial_variance: 1.0171, radius: 1.8846, L1_mu_z: 0.0000, MI_loss: 0.1077, total_loss: 2622.8314
# Epoch 130/200, elbo_loss: 2735.9517, kl_div_f: 4.6571, kl_div_z: 45.4397, fraction_cycling_cells: 0.3789, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3829, entropy_loss: -125.6991, radial_variance: 1.0244, radius: 1.8651, L1_mu_z: 0.0000, MI_loss: 0.1072, total_loss: 2623.8595
# Epoch 131/200, elbo_loss: 2735.7210, kl_div_f: 4.6555, kl_div_z: 45.4425, fraction_cycling_cells: 0.3783, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3829, entropy_loss: -124.4506, radial_variance: 1.0270, radius: 1.8796, L1_mu_z: 0.0000, MI_loss: 0.1054, total_loss: 2624.7173
# Epoch 132/200, elbo_loss: 2735.1771, kl_div_f: 4.6616, kl_div_z: 45.4402, fraction_cycling_cells: 0.3782, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3826, entropy_loss: -123.1997, radial_variance: 1.0184, radius: 1.8532, L1_mu_z: 0.0000, MI_loss: 0.0891, total_loss: 2623.7611
# Epoch 133/200, elbo_loss: 2734.7765, kl_div_f: 4.6580, kl_div_z: 45.4628, fraction_cycling_cells: 0.3780, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3831, entropy_loss: -121.9944, radial_variance: 1.0113, radius: 1.8602, L1_mu_z: 0.0000, MI_loss: 0.0891, total_loss: 2624.5674
# Epoch 134/200, elbo_loss: 2735.2746, kl_div_f: 4.6736, kl_div_z: 45.4604, fraction_cycling_cells: 0.3766, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3827, entropy_loss: -120.7649, radial_variance: 1.0223, radius: 1.8129, L1_mu_z: 0.0000, MI_loss: 0.1000, total_loss: 2627.3466
# Epoch 135/200, elbo_loss: 2734.6932, kl_div_f: 4.6693, kl_div_z: 45.4887, fraction_cycling_cells: 0.3786, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3830, entropy_loss: -119.5738, radial_variance: 1.0096, radius: 1.8473, L1_mu_z: 0.0000, MI_loss: 0.1061, total_loss: 2628.5824
# Epoch 136/200, elbo_loss: 2734.3667, kl_div_f: 4.6721, kl_div_z: 45.4565, fraction_cycling_cells: 0.3718, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3851, entropy_loss: -118.4584, radial_variance: 1.0062, radius: 1.8161, L1_mu_z: 0.0000, MI_loss: 0.1026, total_loss: 2628.9938
# Epoch 137/200, elbo_loss: 2734.2981, kl_div_f: 4.6725, kl_div_z: 45.4639, fraction_cycling_cells: 0.3786, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3824, entropy_loss: -117.1851, radial_variance: 0.9951, radius: 1.8153, L1_mu_z: 0.0000, MI_loss: 0.0987, total_loss: 2629.7934
# Epoch 138/200, elbo_loss: 2734.1836, kl_div_f: 4.6745, kl_div_z: 45.5762, fraction_cycling_cells: 0.3741, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3838, entropy_loss: -116.0670, radial_variance: 1.0047, radius: 1.8175, L1_mu_z: 0.0000, MI_loss: 0.0878, total_loss: 2629.7216
# Epoch 139/200, elbo_loss: 2733.8202, kl_div_f: 4.6711, kl_div_z: 45.6549, fraction_cycling_cells: 0.3719, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3830, entropy_loss: -114.8865, radial_variance: 0.9970, radius: 1.8107, L1_mu_z: 0.0000, MI_loss: 0.0957, total_loss: 2631.3065
# Epoch 140/200, elbo_loss: 2733.7109, kl_div_f: 4.6734, kl_div_z: 45.6437, fraction_cycling_cells: 0.3800, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3818, entropy_loss: -113.7010, radial_variance: 1.0304, radius: 1.8047, L1_mu_z: 0.0000, MI_loss: 0.1000, total_loss: 2632.8414
# Epoch 141/200, elbo_loss: 2733.4177, kl_div_f: 4.6785, kl_div_z: 45.6872, fraction_cycling_cells: 0.3770, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3829, entropy_loss: -112.6079, radial_variance: 0.9923, radius: 1.7952, L1_mu_z: 0.0000, MI_loss: 0.0993, total_loss: 2633.5229
# Epoch 142/200, elbo_loss: 2733.1679, kl_div_f: 4.6773, kl_div_z: 45.7550, fraction_cycling_cells: 0.3786, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3814, entropy_loss: -111.4363, radial_variance: 1.0096, radius: 1.7986, L1_mu_z: 0.0000, MI_loss: 0.1010, total_loss: 2634.6400
# Epoch 143/200, elbo_loss: 2733.2386, kl_div_f: 4.6770, kl_div_z: 45.8321, fraction_cycling_cells: 0.3762, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3835, entropy_loss: -110.3962, radial_variance: 0.9944, radius: 1.7903, L1_mu_z: 0.0000, MI_loss: 0.1046, total_loss: 2636.0916
# Epoch 144/200, elbo_loss: 2733.2989, kl_div_f: 4.6713, kl_div_z: 45.9494, fraction_cycling_cells: 0.3780, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3816, entropy_loss: -109.2377, radial_variance: 0.9691, radius: 1.7951, L1_mu_z: 0.0000, MI_loss: 0.0972, total_loss: 2636.5501
# Epoch 145/200, elbo_loss: 2733.4639, kl_div_f: 4.6806, kl_div_z: 46.0091, fraction_cycling_cells: 0.3772, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3824, entropy_loss: -108.1762, radial_variance: 0.9894, radius: 1.7596, L1_mu_z: 0.0000, MI_loss: 0.1066, total_loss: 2638.6965
# Epoch 146/200, elbo_loss: 2732.8303, kl_div_f: 4.6772, kl_div_z: 45.9464, fraction_cycling_cells: 0.3765, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3828, entropy_loss: -107.1115, radial_variance: 0.9940, radius: 1.7719, L1_mu_z: 0.0000, MI_loss: 0.0989, total_loss: 2638.3792
# Epoch 147/200, elbo_loss: 2732.1044, kl_div_f: 4.6840, kl_div_z: 45.9667, fraction_cycling_cells: 0.3742, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3826, entropy_loss: -106.0413, radial_variance: 1.0017, radius: 1.7346, L1_mu_z: 0.0000, MI_loss: 0.1031, total_loss: 2639.1082
# Epoch 148/200, elbo_loss: 2731.9908, kl_div_f: 4.6814, kl_div_z: 46.0247, fraction_cycling_cells: 0.3759, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3824, entropy_loss: -104.9773, radial_variance: 0.9764, radius: 1.7579, L1_mu_z: 0.0000, MI_loss: 0.0931, total_loss: 2639.0617
# Epoch 149/200, elbo_loss: 2732.3342, kl_div_f: 4.6769, kl_div_z: 46.0587, fraction_cycling_cells: 0.3770, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3813, entropy_loss: -103.8996, radial_variance: 0.9844, radius: 1.7674, L1_mu_z: 0.0000, MI_loss: 0.1030, total_loss: 2641.4899
# Epoch 150/200, elbo_loss: 2732.4775, kl_div_f: 4.6871, kl_div_z: 46.0687, fraction_cycling_cells: 0.3729, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3835, entropy_loss: -102.9318, radial_variance: 0.9881, radius: 1.7248, L1_mu_z: 0.0000, MI_loss: 0.1096, total_loss: 2643.2167
# Epoch 151/200, elbo_loss: 2732.0661, kl_div_f: 4.6817, kl_div_z: 46.0981, fraction_cycling_cells: 0.3739, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3833, entropy_loss: -101.9020, radial_variance: 0.9916, radius: 1.7533, L1_mu_z: 0.0000, MI_loss: 0.1027, total_loss: 2643.1743
# Epoch 152/200, elbo_loss: 2731.8471, kl_div_f: 4.6821, kl_div_z: 46.0595, fraction_cycling_cells: 0.3778, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3812, entropy_loss: -100.8275, radial_variance: 0.9716, radius: 1.7469, L1_mu_z: 0.0000, MI_loss: 0.0899, total_loss: 2642.7294
# Epoch 153/200, elbo_loss: 2732.2117, kl_div_f: 4.6793, kl_div_z: 46.0851, fraction_cycling_cells: 0.3805, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3803, entropy_loss: -99.7960, radial_variance: 0.9909, radius: 1.7231, L1_mu_z: 0.0000, MI_loss: 0.1103, total_loss: 2646.1571
# Epoch 154/200, elbo_loss: 2731.6881, kl_div_f: 4.6874, kl_div_z: 46.0476, fraction_cycling_cells: 0.3831, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3799, entropy_loss: -98.7905, radial_variance: 1.0007, radius: 1.7508, L1_mu_z: 0.0000, MI_loss: 0.1031, total_loss: 2645.9562
# Epoch 155/200, elbo_loss: 2732.2417, kl_div_f: 4.6929, kl_div_z: 46.2203, fraction_cycling_cells: 0.3675, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3799, entropy_loss: -97.8101, radial_variance: 0.9962, radius: 1.7188, L1_mu_z: 0.0000, MI_loss: 0.0902, total_loss: 2646.1701
# Epoch 156/200, elbo_loss: 2731.9708, kl_div_f: 4.6927, kl_div_z: 46.3023, fraction_cycling_cells: 0.3739, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3811, entropy_loss: -96.8703, radial_variance: 0.9809, radius: 1.7181, L1_mu_z: 0.0000, MI_loss: 0.1056, total_loss: 2648.3623
# Epoch 157/200, elbo_loss: 2731.4962, kl_div_f: 4.6878, kl_div_z: 46.3285, fraction_cycling_cells: 0.3787, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3796, entropy_loss: -95.8625, radial_variance: 0.9702, radius: 1.7439, L1_mu_z: 0.0000, MI_loss: 0.1001, total_loss: 2648.3560
# Epoch 158/200, elbo_loss: 2731.5599, kl_div_f: 4.6951, kl_div_z: 46.2067, fraction_cycling_cells: 0.3786, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3808, entropy_loss: -94.9432, radial_variance: 0.9828, radius: 1.7018, L1_mu_z: 0.0000, MI_loss: 0.0991, total_loss: 2649.2153
# Epoch 159/200, elbo_loss: 2731.5397, kl_div_f: 4.6900, kl_div_z: 46.2548, fraction_cycling_cells: 0.3814, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3788, entropy_loss: -93.9443, radial_variance: 0.9933, radius: 1.6942, L1_mu_z: 0.0000, MI_loss: 0.1022, total_loss: 2650.5034
# Epoch 160/200, elbo_loss: 2731.0434, kl_div_f: 4.6914, kl_div_z: 46.3772, fraction_cycling_cells: 0.3806, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3793, entropy_loss: -93.0223, radial_variance: 0.9800, radius: 1.7106, L1_mu_z: 0.0000, MI_loss: 0.1006, total_loss: 2650.7738
# Epoch 161/200, elbo_loss: 2731.0659, kl_div_f: 4.6950, kl_div_z: 46.3179, fraction_cycling_cells: 0.3771, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3797, entropy_loss: -92.1089, radial_variance: 0.9598, radius: 1.7121, L1_mu_z: 0.0000, MI_loss: 0.0970, total_loss: 2651.3297
# Epoch 162/200, elbo_loss: 2731.0979, kl_div_f: 4.6915, kl_div_z: 46.3725, fraction_cycling_cells: 0.3699, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3820, entropy_loss: -91.2520, radial_variance: 0.9697, radius: 1.6811, L1_mu_z: 0.0000, MI_loss: 0.1034, total_loss: 2652.8417
# Epoch 163/200, elbo_loss: 2730.7970, kl_div_f: 4.6928, kl_div_z: 46.4377, fraction_cycling_cells: 0.3723, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3807, entropy_loss: -90.3096, radial_variance: 0.9877, radius: 1.6905, L1_mu_z: 0.0000, MI_loss: 0.1084, total_loss: 2654.0047
# Epoch 164/200, elbo_loss: 2730.8867, kl_div_f: 4.6895, kl_div_z: 46.3507, fraction_cycling_cells: 0.3807, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3755, entropy_loss: -89.2748, radial_variance: 0.9774, radius: 1.7213, L1_mu_z: 0.0000, MI_loss: 0.0845, total_loss: 2652.7574
# Epoch 165/200, elbo_loss: 2729.6650, kl_div_f: 4.6872, kl_div_z: 46.3810, fraction_cycling_cells: 0.3818, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3774, entropy_loss: -88.4371, radial_variance: 0.9664, radius: 1.7078, L1_mu_z: 0.0000, MI_loss: 0.0821, total_loss: 2652.1118
# Epoch 166/200, elbo_loss: 2730.2275, kl_div_f: 4.6947, kl_div_z: 46.3644, fraction_cycling_cells: 0.3783, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3795, entropy_loss: -87.6096, radial_variance: 0.9633, radius: 1.6712, L1_mu_z: 0.0000, MI_loss: 0.0984, total_loss: 2655.0921
# Epoch 167/200, elbo_loss: 2730.0864, kl_div_f: 4.6948, kl_div_z: 46.4053, fraction_cycling_cells: 0.3784, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3784, entropy_loss: -86.7102, radial_variance: 0.9827, radius: 1.6774, L1_mu_z: 0.0000, MI_loss: 0.0972, total_loss: 2655.7582
# Epoch 168/200, elbo_loss: 2729.7054, kl_div_f: 4.6946, kl_div_z: 46.3542, fraction_cycling_cells: 0.3850, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3763, entropy_loss: -85.7949, radial_variance: 0.9740, radius: 1.6860, L1_mu_z: 0.0000, MI_loss: 0.0955, total_loss: 2656.1243
# Epoch 169/200, elbo_loss: 2729.0206, kl_div_f: 4.6984, kl_div_z: 46.3675, fraction_cycling_cells: 0.3788, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3789, entropy_loss: -85.0051, radial_variance: 0.9658, radius: 1.6652, L1_mu_z: 0.0000, MI_loss: 0.0856, total_loss: 2655.2017
# Epoch 170/200, elbo_loss: 2729.3039, kl_div_f: 4.7016, kl_div_z: 46.3926, fraction_cycling_cells: 0.3724, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3804, entropy_loss: -84.1983, radial_variance: 0.9738, radius: 1.6606, L1_mu_z: 0.0000, MI_loss: 0.1023, total_loss: 2657.9749
# Epoch 171/200, elbo_loss: 2729.3608, kl_div_f: 4.7018, kl_div_z: 46.4942, fraction_cycling_cells: 0.3749, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3799, entropy_loss: -83.3471, radial_variance: 0.9745, radius: 1.6540, L1_mu_z: 0.0000, MI_loss: 0.1078, total_loss: 2659.4212
# Epoch 172/200, elbo_loss: 2728.8176, kl_div_f: 4.7002, kl_div_z: 46.4955, fraction_cycling_cells: 0.3759, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3783, entropy_loss: -82.4786, radial_variance: 0.9461, radius: 1.6532, L1_mu_z: 0.0000, MI_loss: 0.0885, total_loss: 2657.7865
# Epoch 173/200, elbo_loss: 2728.8926, kl_div_f: 4.7052, kl_div_z: 46.3883, fraction_cycling_cells: 0.3784, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3779, entropy_loss: -81.6487, radial_variance: 0.9755, radius: 1.6426, L1_mu_z: 0.0000, MI_loss: 0.0983, total_loss: 2659.6966
# Epoch 174/200, elbo_loss: 2728.9489, kl_div_f: 4.7126, kl_div_z: 46.7679, fraction_cycling_cells: 0.3702, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3809, entropy_loss: -80.9089, radial_variance: 0.9506, radius: 1.6260, L1_mu_z: 0.0000, MI_loss: 0.0906, total_loss: 2659.6777
# Epoch 175/200, elbo_loss: 2728.0231, kl_div_f: 4.7040, kl_div_z: 46.5327, fraction_cycling_cells: 0.3755, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3792, entropy_loss: -80.0615, radial_variance: 0.9305, radius: 1.6244, L1_mu_z: 0.0000, MI_loss: 0.1003, total_loss: 2660.5507
# Epoch 176/200, elbo_loss: 2729.0478, kl_div_f: 4.7069, kl_div_z: 46.5878, fraction_cycling_cells: 0.3701, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3803, entropy_loss: -79.2925, radial_variance: 1.0065, radius: 1.6606, L1_mu_z: 0.0000, MI_loss: 0.1048, total_loss: 2662.9069
# Epoch 177/200, elbo_loss: 2728.3857, kl_div_f: 4.7091, kl_div_z: 46.5852, fraction_cycling_cells: 0.3774, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3766, entropy_loss: -78.4163, radial_variance: 0.9635, radius: 1.6431, L1_mu_z: 0.0000, MI_loss: 0.1020, total_loss: 2662.7778
# Epoch 178/200, elbo_loss: 2727.9976, kl_div_f: 4.7074, kl_div_z: 46.4986, fraction_cycling_cells: 0.3797, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3778, entropy_loss: -77.6640, radial_variance: 0.9454, radius: 1.6462, L1_mu_z: 0.0000, MI_loss: 0.1136, total_loss: 2664.2872
# Epoch 179/200, elbo_loss: 2728.1533, kl_div_f: 4.7029, kl_div_z: 46.4916, fraction_cycling_cells: 0.3829, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3761, entropy_loss: -76.8536, radial_variance: 0.9670, radius: 1.6597, L1_mu_z: 0.0000, MI_loss: 0.0856, total_loss: 2662.4903
# Epoch 180/200, elbo_loss: 2727.8323, kl_div_f: 4.7073, kl_div_z: 46.5675, fraction_cycling_cells: 0.3787, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3766, entropy_loss: -76.0989, radial_variance: 0.9375, radius: 1.6227, L1_mu_z: 0.0000, MI_loss: 0.0996, total_loss: 2664.2548
# Epoch 181/200, elbo_loss: 2727.6943, kl_div_f: 4.7147, kl_div_z: 46.8142, fraction_cycling_cells: 0.3723, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3795, entropy_loss: -75.4066, radial_variance: 0.9618, radius: 1.5988, L1_mu_z: 0.0000, MI_loss: 0.1111, total_loss: 2665.9596
# Epoch 182/200, elbo_loss: 2727.4066, kl_div_f: 4.7135, kl_div_z: 46.5839, fraction_cycling_cells: 0.3771, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3786, entropy_loss: -74.6376, radial_variance: 0.9410, radius: 1.6146, L1_mu_z: 0.0000, MI_loss: 0.1022, total_loss: 2665.5435
# Epoch 183/200, elbo_loss: 2726.4048, kl_div_f: 4.7145, kl_div_z: 46.5859, fraction_cycling_cells: 0.3743, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3795, entropy_loss: -73.9143, radial_variance: 0.9464, radius: 1.5888, L1_mu_z: 0.0000, MI_loss: 0.1024, total_loss: 2665.2676
# Epoch 184/200, elbo_loss: 2727.1762, kl_div_f: 4.7122, kl_div_z: 46.6138, fraction_cycling_cells: 0.3793, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3764, entropy_loss: -73.1119, radial_variance: 0.9326, radius: 1.6036, L1_mu_z: 0.0000, MI_loss: 0.1024, total_loss: 2666.8411
# Epoch 185/200, elbo_loss: 2726.1245, kl_div_f: 4.7124, kl_div_z: 46.6219, fraction_cycling_cells: 0.3746, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3777, entropy_loss: -72.4118, radial_variance: 0.9462, radius: 1.5931, L1_mu_z: 0.0000, MI_loss: 0.0833, total_loss: 2664.5807
# Epoch 186/200, elbo_loss: 2726.2613, kl_div_f: 4.7110, kl_div_z: 46.6520, fraction_cycling_cells: 0.3752, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3780, entropy_loss: -71.6982, radial_variance: 0.9279, radius: 1.5856, L1_mu_z: 0.0000, MI_loss: 0.1014, total_loss: 2667.2165
# Epoch 187/200, elbo_loss: 2725.6010, kl_div_f: 4.7118, kl_div_z: 46.6145, fraction_cycling_cells: 0.3781, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3768, entropy_loss: -70.9587, radial_variance: 0.9391, radius: 1.5897, L1_mu_z: 0.0000, MI_loss: 0.1020, total_loss: 2667.3731
# Epoch 188/200, elbo_loss: 2725.9723, kl_div_f: 4.7104, kl_div_z: 46.5364, fraction_cycling_cells: 0.3815, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3748, entropy_loss: -70.2111, radial_variance: 0.9356, radius: 1.5812, L1_mu_z: 0.0000, MI_loss: 0.0973, total_loss: 2668.0117
# Epoch 189/200, elbo_loss: 2725.8489, kl_div_f: 4.7158, kl_div_z: 46.5484, fraction_cycling_cells: 0.3791, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3758, entropy_loss: -69.5339, radial_variance: 0.9401, radius: 1.5788, L1_mu_z: 0.0000, MI_loss: 0.0980, total_loss: 2668.6384
# Epoch 190/200, elbo_loss: 2725.9251, kl_div_f: 4.7161, kl_div_z: 46.5790, fraction_cycling_cells: 0.3781, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3740, entropy_loss: -68.8047, radial_variance: 0.9344, radius: 1.5617, L1_mu_z: 0.0000, MI_loss: 0.0972, total_loss: 2669.3406
# Epoch 191/200, elbo_loss: 2726.5372, kl_div_f: 4.7195, kl_div_z: 46.6420, fraction_cycling_cells: 0.3759, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3757, entropy_loss: -68.1540, radial_variance: 0.9530, radius: 1.5912, L1_mu_z: 0.0000, MI_loss: 0.0914, total_loss: 2670.0652
# Epoch 192/200, elbo_loss: 2726.7296, kl_div_f: 4.7193, kl_div_z: 46.6392, fraction_cycling_cells: 0.3747, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3761, entropy_loss: -67.4846, radial_variance: 0.9524, radius: 1.5790, L1_mu_z: 0.0000, MI_loss: 0.0897, total_loss: 2670.7426
# Epoch 193/200, elbo_loss: 2726.0687, kl_div_f: 4.7142, kl_div_z: 46.6644, fraction_cycling_cells: 0.3769, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3746, entropy_loss: -66.7839, radial_variance: 0.9493, radius: 1.5847, L1_mu_z: 0.0000, MI_loss: 0.1019, total_loss: 2672.0047
# Epoch 194/200, elbo_loss: 2725.3364, kl_div_f: 4.7151, kl_div_z: 46.6528, fraction_cycling_cells: 0.3765, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3759, entropy_loss: -66.1432, radial_variance: 0.9250, radius: 1.5784, L1_mu_z: 0.0000, MI_loss: 0.0967, total_loss: 2671.3624
# Epoch 195/200, elbo_loss: 2725.0342, kl_div_f: 4.7128, kl_div_z: 46.6655, fraction_cycling_cells: 0.3777, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3753, entropy_loss: -65.4732, radial_variance: 0.9466, radius: 1.5817, L1_mu_z: 0.0000, MI_loss: 0.0989, total_loss: 2671.9800
# Epoch 196/200, elbo_loss: 2725.7113, kl_div_f: 4.7193, kl_div_z: 46.6756, fraction_cycling_cells: 0.3723, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3774, entropy_loss: -64.8622, radial_variance: 0.9426, radius: 1.5593, L1_mu_z: 0.0000, MI_loss: 0.1051, total_loss: 2673.8599
# Epoch 197/200, elbo_loss: 2725.9675, kl_div_f: 4.7110, kl_div_z: 46.7173, fraction_cycling_cells: 0.3817, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3729, entropy_loss: -64.1316, radial_variance: 0.9384, radius: 1.5827, L1_mu_z: 0.0000, MI_loss: 0.1017, total_loss: 2674.5297
# Epoch 198/200, elbo_loss: 2725.0210, kl_div_f: 4.7252, kl_div_z: 46.7590, fraction_cycling_cells: 0.3704, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3771, entropy_loss: -63.5729, radial_variance: 0.9475, radius: 1.5576, L1_mu_z: 0.0000, MI_loss: 0.0938, total_loss: 2673.3334
# Epoch 199/200, elbo_loss: 2725.5720, kl_div_f: 4.7137, kl_div_z: 46.8243, fraction_cycling_cells: 0.3833, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3714, entropy_loss: -62.8345, radial_variance: 0.9291, radius: 1.5774, L1_mu_z: 0.0000, MI_loss: 0.1019, total_loss: 2675.4365
# Epoch 200/200, elbo_loss: 2725.8361, kl_div_f: 4.7184, kl_div_z: 46.7938, fraction_cycling_cells: 0.3810, l2_px_rate: 0.0000, entropy_loss_unweighted: -3.3689, entropy_loss: -62.1632, radial_variance: 0.9382, radius: 1.5555, L1_mu_z: 0.0000, MI_loss: 0.0935, total_loss: 2675.5213

# %%
# Get the infered theta values
model.to("cpu")
generative_outputs, space_outputs = model.get_outputs()
thetas = space_outputs["theta"].detach().numpy()
sns.histplot(thetas, bins=100)
# Out:
# <Axes: ylabel='Count'>

# %%
i_cycling = space_outputs["cycling_logits"].detach().numpy() > 25
i_cycling = np.where(i_cycling)[0]

# %%
i_g1 = (
    adata.obs[space_outputs["cycling_logits"].detach().numpy() < 25]
    .sample(frac=0.3)
    .index
)

# %%
sns.histplot(x=space_outputs["b_z"].detach().numpy() > 0.5)
# Out:
# <Axes: ylabel='Count'>

# %%
cycling_cells = space_outputs["b_z"] > 0.5

# %%
thetas = model.infer_pseudotimes(adata, "total")

# %%
g1_g0_cells = ((thetas > -1.75) & (thetas < -1.25)).numpy()

# %%
def match_phase_distributions(phases1, phases2, n_bins=20):
    """
    Find indices from phases1 that match the distribution of phases2.

    Parameters:
    -----------
    phases1 : array-like
        First array of phases (between -pi and pi)
    phases2 : array-like
        Second array of phases (between -pi and pi) - target distribution
    n_bins : int
        Number of bins to use for phase distribution

    Returns:
    --------
    indices : ndarray
        Indices from phases1 that match phases2 distribution
    """
    phases1 = np.asarray(phases1)
    phases2 = np.asarray(phases2)

    # Create bins from -pi to pi
    bins = np.linspace(-np.pi, np.pi, n_bins + 1)

    # Bin both phase arrays
    bin_indices1 = np.digitize(phases1, bins) - 1
    bin_indices2 = np.digitize(phases2, bins) - 1

    # Clip to valid range [0, n_bins-1]
    bin_indices1 = np.clip(bin_indices1, 0, n_bins - 1)
    bin_indices2 = np.clip(bin_indices2, 0, n_bins - 1)

    # Count how many samples we need from each bin (target distribution)
    target_counts = np.bincount(bin_indices2, minlength=n_bins)

    # Find which elements of phases1 belong to each bin
    bin_members = [np.where(bin_indices1 == i)[0] for i in range(n_bins)]

    # Calculate the maximum scaling factor where 95% of bins have enough samples
    # Find bins that have non-zero target counts
    active_bins = target_counts > 0
    n_active_bins = np.sum(active_bins)

    if n_active_bins == 0:
        return np.array([], dtype=int)

    # Calculate availability ratio for each active bin
    availability_ratios = np.zeros(n_bins)
    for bin_idx in range(n_bins):
        if target_counts[bin_idx] > 0:
            available_count = len(bin_members[bin_idx])
            availability_ratios[bin_idx] = available_count / target_counts[bin_idx]

    # Sort ratios for active bins and find the 5th percentile
    # (95% of bins will have at least this ratio)
    active_ratios = availability_ratios[active_bins]
    active_ratios_sorted = np.sort(active_ratios)
    percentile_5_idx = max(0, int(np.ceil(0.05 * len(active_ratios_sorted))) - 1)
    scaling_factor = active_ratios_sorted[percentile_5_idx]

    # Scale down all target counts by this factor
    scaled_counts = np.floor(target_counts * scaling_factor).astype(int)

    # Sample from each bin according to scaled counts
    selected_indices = []

    for bin_idx in range(n_bins):
        available = bin_members[bin_idx]
        needed = scaled_counts[bin_idx]

        if needed == 0 or len(available) == 0:
            continue

        # Randomly sample without replacement (no reusing indices)
        needed = min(needed, len(available))
        chosen = np.random.choice(available, size=needed, replace=False)
        selected_indices.extend(chosen)

    return np.array(selected_indices, dtype=int)

# %%
g1_g0_cells = match_phase_distributions(
    thetas[cycling_cells.detach().numpy()],
    thetas[~cycling_cells.detach().numpy()],
    n_bins=100,
)
# get indices in the original adata
g1_g0_indices = adata[cycling_cells.detach().numpy()].obs.index[g1_g0_cells]
# transform it into a mask
g1_g0_indices = adata.obs.index.isin(g1_g0_indices)

# %%
cycling_cells[g1_g0_indices]
# Out:
# tensor([True, True, True,  ..., True, True, True])

# %%
sns.histplot(thetas[g1_g0_indices], bins=30)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(thetas[~cycling_cells], bins=30)
# Out:
# <Axes: ylabel='Count'>

# %%
from cophaser.model import interpretability

g1_g0_cells = ((thetas > -1.75) & (thetas < -1.25)).numpy()
res = {}
for subtype in adata.obs["orig.ident"].unique():
    print(subtype)
    i = adata.obs["orig.ident"] == subtype
    i = i & g1_g0_cells
    gene_importance = interpretability.compute_feature_importance(
        model, space_field="b_z", batch_size=2048, device="cuda", mask_cells=i
    )
    gene_importance = pd.Series(
        gene_importance[0], index=model.context_genes
    ).sort_values(ascending=False, key=abs)
    res[subtype] = gene_importance
# Out:
# TN
# /home/maxine/Documents/paychere/CoPhaser/src/CoPhaser/model/interpretability.py:90: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x_variable = x_variable[mask_cells]
# /home/maxine/Documents/paychere/CoPhaser/src/CoPhaser/model/interpretability.py:91: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   library_size = library_size[mask_cells]
# HER2
# ER

# %%
# find genes in top 20 that are not in SMALL_CYCLING_GENE_SET
for subtype in res:
    print(subtype)
    print(
        res[subtype].head(50)[~res[subtype].head(50).index.isin(SMALL_CYCLING_GENE_SET)]
    )
# Out:
# TN
# SCGB2A2   -0.029061
# CD24      -0.025058
# MUCL1      0.023816
# KRT14      0.023289
# TFF3      -0.022967
# dtype: float32
# HER2
# KRT14    0.543976
# FDCSP    0.231713
# MUCL1   -0.217058
# IFI27   -0.208168
# CPB1     0.205909
# dtype: float32
# ER
# KRT14    0.102053
# FDCSP    0.050506
# RPL19   -0.049679
# dtype: float32

# %%
pd.Series(gene_importance[0], index=model.context_genes).sort_values(
    ascending=False, key=lambda x: x
)
# Out:
# /tmp/ipykernel_372464/780698642.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pd.Series(gene_importance[0], index=model.context_genes).sort_values(
# MT1A         -0.945535
# NFE2         -0.945535
# ANGPTL4      -0.945535
# CORO6        -0.945535
# AC093010.2   -0.945535
#                 ...
# AC106707.1   -0.945535
# KRT7         -0.945535
# GAS6         -0.945535
# TGM2         -0.945535
# FCRLB        -0.945535
# Length: 2085, dtype: float32

# %%
def get_gene_fractions(gene_name, adata, layer="total"):
    library_size = adata.layers[layer].sum(axis=1)
    library_size = np.array(library_size).flatten()
    gene_fractions = (
        adata[:, gene_name].layers[layer].toarray().flatten() / library_size
    )
    return gene_fractions

# %%
g1_g0_cells = g1_g0_cells & (adata.obs["orig.ident"] == "TN")

# %%
cycling_cells[g1_g0_cells]
# Out:
# /tmp/ipykernel_372464/1359448123.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cycling_cells[g1_g0_cells]
# tensor([False, False,  True,  ..., False,  True, False])

# %%
gene = "BIRC5"
# total_frac = 0
# for gene in SMALL_CYCLING_GENE_SET:
#     gene_fractions = get_gene_fractions(gene, adata[(g1_g0_indices)|(~cycling_cells.numpy())])
#     total_frac += gene_fractions
total_frac = get_gene_fractions(gene, adata[(g1_g0_indices) | (~cycling_cells.numpy())])

barplot_df = pd.DataFrame(
    {
        "gene_fractions": np.log(1 + total_frac * 1e4),
        "cycling_status": cycling_cells[(g1_g0_indices) | (~cycling_cells.numpy())],
    }
)
sns.barplot(
    data=barplot_df,
    x="cycling_status",
    y="gene_fractions",
    ax=plt.gca(),
)
plt.title(f"{gene} expression in G1/G0 cells")
plt.ylabel(f"log(1 + {gene} counts per 10k reads)")
plt.xlabel("Model's cycling status")
print(barplot_df.groupby("cycling_status").mean())
# Out:
#                 gene_fractions
# cycling_status
# False                 0.012189
# True                  0.070846

# %%
sns.histplot(x=thetas[~adata.obs["cycling"]])
# ad vertical lines at -1.25 and -1.75
plt.axvline(-1.25, color="red", linestyle="--")
plt.axvline(-1.75, color="red", linestyle="--")
# Out:
# /tmp/ipykernel_372464/3920066266.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sns.histplot(x=thetas[~adata.obs["cycling"]])

# %%
cells_projected = space_outputs["x_projected"].detach().numpy()
sns.histplot(x=cells_projected[cycling_cells, 0], y=cells_projected[cycling_cells, 1])
# Out:
# <Axes: >

# %%
sns.histplot(x=cells_projected[:, 0], y=cells_projected[:, 1])
# Out:
# <Axes: >

# %%
sns.histplot(x=thetas[~cycling_cells])
# Out:
# <Axes: xlabel='None', ylabel='Count'>

# %%
def add_theta(df, theta, theta_pca):
    df["inferred_theta"] = theta
    df["pca_theta"] = theta_pca
    return df


df_mean = pd.DataFrame(
    generative_outputs["px_rate"].detach().numpy(), columns=model.context_genes
)
df_mean = add_theta(df_mean, thetas, adata.obs["pca_theta"].values)
# df_rhythmic = pd.DataFrame(generative_outputs["rhythmic_term"].detach().numpy(), columns=model.rhythmic_gene_names)
df_rhythmic = pd.DataFrame(
    generative_outputs["F"].detach().numpy(), columns=model.context_genes
)
df_rhythmic = add_theta(df_rhythmic, thetas, adata.obs["pca_theta"].values)
df_z = pd.DataFrame(
    generative_outputs["Z"].detach().numpy(), columns=model.context_genes
)
df_z = add_theta(df_z, thetas, adata.obs["pca_theta"].values)

# %%
sns.scatterplot(
    data=df_mean, x=df_mean["inferred_theta"], y=df_mean["pca_theta"], alpha=0.5
)
# Out:
# <Axes: xlabel='inferred_theta', ylabel='pca_theta'>

# %%
plotting.plot_model_decoded_space(
    df_rhythmic.loc[cycling_cells.detach().numpy()],
    gene_to_upper=True,
    title="Fourier component of gene expression",
)
# Out:
# /home/maxine/Documents/paychere/CoPhaser/src/CoPhaser/plotting.py:548: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[i].legend(loc="upper left", bbox_to_anchor=(1, 1))

# %%
library_size = adata.layers["total"].sum(axis=1).A1

# %%
# plot the two with different y scales
genes = ["Top2a", "Pcna", "Mki67", "Mcm6"]
plotting.plot_gene_profile(
    df_mean, adata, genes, layer_to_use="total", library_size=library_size
)

# %%
utils.add_histones_fraction(adata=adata, layer="total")

adata.obs["library_size"] = library_size
adata.obs["inferred_theta"] = utils.normalize_angles(
    df_mean["inferred_theta"].to_numpy()
)
plotting.plot_smoothed_size_evolution(
    adata[cycling_cells.detach().numpy()],
    "inferred_theta",
    counts_sum_field="histones_fraction",
    hue="cancer_type",
)

# %%
fig, ax = plotting.modify_axis_labels()
sns.histplot(
    x=df_z.loc[cycling_cells.numpy(), "inferred_theta"],
    hue=adata[cycling_cells.numpy()].obs["cancer_type"].values,
    stat="density",
    common_norm=False,
    ax=ax,
    element="poly",
    bins=10,
)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %%
df_barplot = pd.DataFrame(
    {
        "cancer_type": adata.obs["cancer_type"].values,
        "cycling_status": cycling_cells.numpy(),
    }
)
df_barplot = df_barplot.groupby("cancer_type")["cycling_status"].mean().reset_index()
sns.barplot(data=df_barplot, x="cancer_type", y="cycling_status")
# Out:
# <Axes: xlabel='cancer_type', ylabel='cycling_status'>

# %%
torch.arctan2(
    model.rhythmic_decoder.fourier_coefficients.weight[model.rhythmic_gene_indices, 1],
    model.rhythmic_decoder.fourier_coefficients.weight[model.rhythmic_gene_indices, 0],
)
# Out:
# tensor([0.6329, 2.3617, 0.7384, 2.0344, 2.5364, 1.2662, 2.6269, 1.0162, 1.0591,
#         0.7973, 0.3408, 2.3976, 2.4052, 2.0135, 0.0810, 2.1737, 2.0995, 2.0121,
#         0.4450, 0.7093, 2.1029, 2.3863, 1.5280, 0.3545, 1.6000, 1.9848, 2.0004,
#         1.0640, 0.4940, 1.4489, 0.3401, 0.8820, 2.0666, 0.7359, 2.3379, 2.0815,
#         2.3003, 2.4378, 0.2454, 0.3014, 0.5169, 2.3231, 0.9240, 1.2219, 2.5570,
#         0.4439, 2.2093, 2.1768, 0.9902, 2.1913, 1.9943, 2.4551, 2.3421, 1.9916,
#         2.1146, 0.4618, 2.1729, 0.7114, 2.2008, 1.2543, 1.3028, 1.3065, 1.5199,
#         2.2650, 0.8279, 1.5609, 0.6181, 1.3443, 2.0397, 2.1093, 2.2282, 2.1924,
#         0.6427, 1.6677, 2.1120, 2.2932, 2.0114, 0.5638, 2.5359, 1.0504, 2.3000,
#         2.3335, 2.0038, 0.8972, 0.6472, 1.8049, 2.4407, 2.1754, 2.3461, 2.5111,
#         1.8032, 2.2123, 2.0344, 1.5868, 0.5427, 2.3687, 2.4536, 1.0556],
#        device='cuda:0', grad_fn=<Atan2Backward0>)

# %%
plotting.plot_model_decoded_space(
    df_z,
    gene_to_upper=True,
    hue=adata.obs["cancer_type"].values,
    title="Z component of gene expression",
)

# %%
df_z_diff = df_z.groupby(by=adata.obs["cancer_type"].values).mean()
df_z_diff = df_z_diff.loc[:, df_z_diff.columns.isin(SMALL_CYCLING_GENE_SET)]
df_z_diff = df_z_diff - df_z_diff.mean()
df_z_diff.abs().max().sort_values(ascending=False).head(10)
# Out:
# CDCA7     1.277037
# CDC20     0.841870
# ANP32E    0.839455
# PIMREG    0.820054
# NDC80     0.802113
# CDC45     0.791937
# TYMS      0.714220
# CDCA2     0.691310
# HMGB2     0.628248
# CDCA3     0.611821
# dtype: float32

# %%
adata_deg = adata.copy()
adata_deg.X = adata_deg.layers["total"]
adata_deg = adata_deg[:, g]
sc.pp.normalize_total(adata_deg, target_sum=1e4)
sc.pp.log1p(adata_deg)
sc.tl.rank_genes_groups(
    adata_deg, "cancer_type", method="wilcoxon", key_added="wilcoxon"
)
sc.pl.rank_genes_groups(adata_deg, n_genes=25, sharey=False, key="wilcoxon")
# Out:
# /home/maxine/miniconda3/envs/CoPhaser_Env/lib/python3.13/site-packages/scanpy/preprocessing/_normalization.py:269: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
plotting.plot_model_decoded_space(
    df_z,
    gene_to_upper=True,
    hue=adata.obs["cancer_type"].values,
    title="Z component of gene expression",
    genes=["CDC20", "PIMREG", "UBE2C", "NDC80"],
)

# %%
plotting.plot_gene_profile(
    df_mean,
    adata,
    genes=["CDC20", "PIMREG", "UBE2C", "NDC80"],
    layer_to_use="total",
    library_size=library_size,
    hue=adata.obs["cancer_type"].values,
)

# %%
df_counts_norm = pd.DataFrame(
    np.log1p(
        adata[:, g].layers["total"].todense() / library_size.reshape(-1, 1) * 10e4
    ),
    index=adata.raw,
    columns=g,
)

# %%
df_counts_norm["inferred_theta"] = df_mean["inferred_theta"].values
df_counts_norm["cancer_type"] = adata.obs["cancer_type"].values

# %%
adata.obs["library_size"] = library_size
adata.obs["inferred_theta"] = df_mean["inferred_theta"].to_numpy()

# %%
plotting.plot_smoothed_size_evolution(adata, "inferred_theta", hue="cancer_type")

# %%
sns.scatterplot(
    x=df_mean["inferred_theta"], y=library_size, hue=adata.obs["cancer_type"].values
)
# Out:
# <Axes: xlabel='inferred_theta'>

# %%
plotting.plot_smoothed_size_evolution(adata, "pca_theta", hue="cancer_type")

# %%
plotting.plot_z_space(
    space_outputs["z"],
    adata.obs["group"].astype("category"),
    adata.obs["inferred_theta"],
    cell_identity_label="patient",
)

# %%
plotting.plot_cell_cycle(df_rhythmic)
# Out:
# /home/maxine/Documents/paychere/CoPhaser/src/CoPhaser/plotting.py:232: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels)

# %%
import umap

reducer = umap.UMAP()
embedding = reducer.fit_transform(space_outputs["z"].detach().numpy())
sns.scatterplot(x=embedding[:, 0], y=embedding[:, 1], hue=adata.obs["cancer_type"])
# Out:
# <Axes: >

# %%
logits = space_outputs["cycling_logits"].detach().numpy()
logits
# Out:
# array([ 7.0091424,  8.895044 , 20.       , ..., -2.8017106, -2.5887604,
#        -2.263787 ], dtype=float32)

# %%
cells_in_g1_g0 = ((thetas > -1.75) & (thetas < -1.25)).numpy()

# %%
space_outputs["b_z"] > 0.5
# Out:
# tensor([ True,  True,  True,  ..., False, False, False])

# %%
sns.histplot(x=logits[~cycling_cells], hue=(cells_in_g1_g0[~cycling_cells]))
# Out:
# <Axes: ylabel='Count'>

# %%
to_save = {
    "z_space_embedding": embedding,
    "inferred_theta": df_mean["inferred_theta"].to_numpy(),
    "cycling_cells": cycling_cells.detach().numpy(),
    "latent_z": space_outputs["z"].detach().numpy(),
    "adata": adata,
    "df_f": df_rhythmic,
    "df_z": df_z,
    "df_mean": df_mean,
    "integrated_gradients": res,
    "logits": space_outputs["cycling_logits"].detach().numpy(),
}

# %%
# import pickle

# with open("data/breast_cancer_results.pkl", "wb") as f:
#     pickle.dump(to_save, f)
